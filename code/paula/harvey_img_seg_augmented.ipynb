# %% [markdown]
# # IMAGE SEGMENTATION

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import datetime
import os
import PIL


from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import TensorBoard

# %matplotlib inline
# !pip install livelossplot
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
from sklearn.model_selection import train_test_split
from livelossplot import PlotLossesKeras
# Out:
# Requirement already satisfied: livelossplot in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from livelossplot) (3.2.2)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.7/dist-packages (from livelossplot) (2.3.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from livelossplot) (5.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (3.13)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (3.10.0.2)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (1.19.5)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (5.1.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (2.11.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (2.8.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh->livelossplot) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh->livelossplot) (3.0.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh->livelossplot) (1.15.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->livelossplot) (5.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->livelossplot) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->livelossplot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->livelossplot) (0.7.0)

# %%
print("TensorFlow version: ",tf.__version__)
# Out:
# TensorFlow version:  2.7.0

# %% [markdown]
# Checking the available CPU and GPU devices

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print(tf.config.list_physical_devices())
# Out:
# Num GPUs Available:  1
# Num CPUs Available:  1
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Initial Preparation

# %% [markdown]
# ### Train data

# %% [markdown]
# Setting the path to train images and masks.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_x_loc = "/content/drive/MyDrive/DL/train_images.zip (Unzipped Files)/train_images/"
train_y_loc = "/content/drive/MyDrive/DL/train_masks.zip (Unzipped Files)/train_masks/"

# %% [markdown]
# Extract the names of the image files and sort and store them in a list. This will later be iterated over to read and store the image and mask data.

# %%
img_names = [s[:-4] for s in os.listdir(train_x_loc)]

# %% [markdown]
# In order to prevent clogging up the RAM, we will create batches of images.

# %%
TRAIN_BATCH_SIZE = 87

# %%
img_names_batches = [img_names[i:i + TRAIN_BATCH_SIZE] for i in range(0, len(img_names), TRAIN_BATCH_SIZE)]
print("Train images were split into batches of size {}.".format(TRAIN_BATCH_SIZE))
print("Number of batches = ",len(img_names_batches))
# Out:
# Train images were split into batches of size 87.
# Number of batches =  3

# %% [markdown]
# ### Image Configs

# %%
INPUT_SIZE = 512
N_CHANNEL = 3
N_CLASSES = 27

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### UNet

# %%
def get_unet():
    inputs = Input((INPUT_SIZE, INPUT_SIZE, N_CHANNEL))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    drop1 = Dropout(0.2)(pool1) # Dropout(0.2)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(drop1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    drop2 = Dropout(0.2)(pool2) #Dropout(0.2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(drop2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    drop3 = Dropout(0.2)(pool3) 

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    drop4 = Dropout(0.2)(pool4) # Dropout(0.2)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(drop4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv9)

    conv10 = Conv2D(N_CLASSES, (1, 1), activation="softmax")(conv9) #

    model = tf.keras.Model(inputs=[inputs], outputs=[conv10])

    return model

# %% [markdown]
# In semantic segmentation, you need as many masks as you have object classes.
# In our dataset, each pixel in every mask has been assigned a single integer probability that it belongs to a
# certain class - 0 to 26. The correct class is the one with the highest probability.
#
# Sparse categorical crossentropy is more efficient than other loss functions when you're dealing with
# lots of classes and to perform pixel-wise multiclass prediction.

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Creating CallBacks
#
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc).

# %%
# TensorBoard visuluaziations
# To visualize, execute the following commands in a new jupyter notebook:
# %load_ext tensorboard
# %tensorboard --logdir /tmp/tboard_logs8
tensorboard = TensorBoard(log_dir='/tmp/tboard_logs8', histogram_freq=0, write_graph=True, write_images=True)

class MyCustomCallback(tf.keras.callbacks.Callback):

  def on_train_batch_begin(self, batch, logs=None):
    print('\nTraining: batch {} begins at {}'.format(batch, datetime.datetime.now().time()))

  def on_train_batch_end(self, batch, logs=None):
    print('\nTraining: batch {} ends at {}'.format(batch, datetime.datetime.now().time()))

  def on_test_batch_begin(self, batch, logs=None):
    print('\nEvaluating: batch {} begins at {}'.format(batch, datetime.datetime.now().time()))

  def on_test_batch_end(self, batch, logs=None):
    print('\nEvaluating: batch {} ends at {}'.format(batch, datetime.datetime.now().time()))

# %% [markdown]
# ### Training

# %%
# img_names_batches = [img_names_batches[0]]

# %%
for i, imgnames in enumerate(img_names_batches):
    print(i, len(imgnames))
# Out:
# 0 87
# 1 87
# 2 87

# %%
aug = ImageDataGenerator(
           vertical_flip=True,horizontal_flip=True)  #  fill_mode='reflect' se 'constant'?? / reflect

# aug = ImageDataGenerator(rotation_range=45.,
#            width_shift_range=0.2,
#            height_shift_range=0.2,
#            shear_range=0.2,
#            zoom_range=0.2,
#            horizontal_flip=True,
#            vertical_flip=True,
#            fill_mode='reflect')
#EXPLANATION: https://www.pyimagesearch.com/2018/12/24/how-to-use-keras-fit-and-fit_generator-a-hands-on-tutorial/

# %%
# Training configs
EPOCHS = 25
LEARNING_RATE = 0.001
TRAINING_SAVE_LOC = "saved_models/training_20/"
early_stopping = EarlyStopping(monitor="loss",patience=10, verbose=1)
BS = 10

model = None

train_hist = {}

for b,img_names in enumerate(img_names_batches):
    
#     if len(img_names) > 90:
#         EPOCHS = 30
#         print("EPOCHS set to ", EPOCHS)
#     elif len(img_names) < 70:
#         EPOCHS = 5
#         print("EPOCHS set to ", EPOCHS)
#     else:
#         EPOCHS = 20
#         print("EPOCHS set to ", EPOCHS)
    
    # Setting the model
    if model is None:
        print("No model set. Creating new model.")
        model = get_unet()
        model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False), 
              metrics=['accuracy'])
        INITIAL_TRAIN = False
        print("UNet model created from scratch.")
    else:
        model = tf.keras.models.load_model(TRAINING_SAVE_LOC + "batch_" + str(b - 1) + "/")
        print("UNet model loaded from ", TRAINING_SAVE_LOC + "batch_" + str(b - 1) + "/")
        
    if model is None:
            print("!!! MODEL NOT SET !!!")
            break
              
    # Preparing the data
    x = []
    y = []
    print("Reading train data")
    for i in img_names:
        x.append(np.array(PIL.Image.open(train_x_loc + i + ".jpg").resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST))/255)
        y.append(to_categorical(np.array(PIL.Image.open(train_y_loc + i + ".png").resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST)), N_CLASSES))
    x = np.array(x)
    y = np.array(y)
    # Reserve samples for validation
    val_samples = 27
    x_train = x[:-val_samples]
    print("x train ---- ", len(x_train))
    y_train = y[:-val_samples]
    x_val = x[-val_samples:]
    print("x val ---- ", len(x_val))
    y_val = y[-val_samples:]
    del x,y
    print("Train and Validation data created")
    

    # Training the model
    #model_history = model.fit(x_train, y_train, batch_size=5, epochs=EPOCHS, validation_data=(x_val, y_val), shuffle=True, callbacks=[MyCustomCallback(),tensorboard])
    model_history2 = model.fit_generator(aug.flow(x_train, y_train, batch_size=BS), 
          steps_per_epoch = len(x_train)//BS,
          validation_data=(x_val, y_val),
          validation_steps = len(x_train)//BS,
          epochs = EPOCHS, 
          workers = 4,
          use_multiprocessing = True,
          callbacks=[MyCustomCallback(),tensorboard])
    
    train_hist[b] = model_history2
    print("Train hist recorded for batch - ",b)
    del x_train,y_train,x_val,y_val
    
    # Saving the model
    print("Saving the model")
    BATCH_LOC = "batch_" + str(b) + "/"
    CURRENT_SAVE_LOC = TRAINING_SAVE_LOC + BATCH_LOC
    model.save(CURRENT_SAVE_LOC)
#     model.save(CURRENT_SAVE_LOC,save_format='h5')
    print("Saved the model at", CURRENT_SAVE_LOC)
# Out:
# No model set. Creating new model.
# UNet model created from scratch.
# Reading train data
# x train ----  60
# x val ----  27
# Train and Validation data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:70: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/25
#
# Training: batch 0 begins at 11:11:23.073338
#
# Training: batch 0 ends at 11:11:28.530908
# 1/6 [====>.........................] - ETA: 27s - loss: 3.6271 - accuracy: 0.0154
# Training: batch 1 begins at 11:11:28.960075
#
# Training: batch 1 ends at 11:11:29.742295
# 2/6 [=========>....................] - ETA: 4s - loss: 3.4655 - accuracy: 0.0315
# Training: batch 2 begins at 11:11:29.744715
#
# Training: batch 2 ends at 11:11:30.112736
# 3/6 [==============>...............] - ETA: 2s - loss: 3.3709 - accuracy: 0.0301
# Training: batch 3 begins at 11:11:30.115404
#
# Training: batch 3 ends at 11:11:30.481682
# 4/6 [===================>..........] - ETA: 1s - loss: 3.2817 - accuracy: 0.0591
# Training: batch 4 begins at 11:11:30.484104
#
# Training: batch 4 ends at 11:11:30.855678
# 5/6 [========================>.....] - ETA: 0s - loss: 3.2437 - accuracy: 0.0941
# Training: batch 5 begins at 11:11:30.858471
#
# Training: batch 5 ends at 11:11:31.856857
# 6/6 [==============================] - ETA: 0s - loss: 3.1890 - accuracy: 0.1346
# Evaluating: batch 0 begins at 11:11:33.580138
#
# Evaluating: batch 0 ends at 11:11:34.788377
#
# Evaluating: batch 1 begins at 11:11:34.789572
#
# Evaluating: batch 1 ends at 11:11:34.862062
#
# Evaluating: batch 2 begins at 11:11:34.863292
#
# Evaluating: batch 2 ends at 11:11:34.939940
#
# Evaluating: batch 3 begins at 11:11:34.941119
#
# Evaluating: batch 3 ends at 11:11:35.024123
#
# Evaluating: batch 4 begins at 11:11:35.025619
#
# Evaluating: batch 4 ends at 11:11:35.229490
#
# Evaluating: batch 5 begins at 11:11:35.231423
#
# Evaluating: batch 5 ends at 11:11:35.267045
# 6/6 [==============================] - 12s 1s/step - loss: 3.1890 - accuracy: 0.1346 - val_loss: 3.0394 - val_accuracy: 0.2872
# Epoch 2/25
#
# Training: batch 0 begins at 11:11:35.358875
#
# Training: batch 0 ends at 11:11:40.410171
# 1/6 [====>.........................] - ETA: 25s - loss: 2.7893 - accuracy: 0.3539
# Training: batch 1 begins at 11:11:40.416988
#
# Training: batch 1 ends at 11:11:40.832221
# 2/6 [=========>....................] - ETA: 1s - loss: 2.8953 - accuracy: 0.3181
# Training: batch 2 begins at 11:11:40.835438
#
# Training: batch 2 ends at 11:11:41.269012
# 3/6 [==============>...............] - ETA: 1s - loss: 2.7986 - accuracy: 0.3386
# Training: batch 3 begins at 11:11:41.273278
#
# Training: batch 3 ends at 11:11:41.625565
# 4/6 [===================>..........] - ETA: 0s - loss: 2.8096 - accuracy: 0.3196
# Training: batch 4 begins at 11:11:41.628056
#
# Training: batch 4 ends at 11:11:42.007549
# 5/6 [========================>.....] - ETA: 0s - loss: 2.7816 - accuracy: 0.3277
# Training: batch 5 begins at 11:11:42.010428
#
# Training: batch 5 ends at 11:11:42.934824
# 6/6 [==============================] - ETA: 0s - loss: 2.7682 - accuracy: 0.3328
# Evaluating: batch 0 begins at 11:11:42.972002
#
# Evaluating: batch 0 ends at 11:11:43.466113
#
# Evaluating: batch 1 begins at 11:11:43.468494
#
# Evaluating: batch 1 ends at 11:11:43.555367
#
# Evaluating: batch 2 begins at 11:11:43.556578
#
# Evaluating: batch 2 ends at 11:11:43.646551
#
# Evaluating: batch 3 begins at 11:11:43.648170
#
# Evaluating: batch 3 ends at 11:11:43.741498
#
# Evaluating: batch 4 begins at 11:11:43.743308
#
# Evaluating: batch 4 ends at 11:11:43.843468
#
# Evaluating: batch 5 begins at 11:11:43.845055
#
# Evaluating: batch 5 ends at 11:11:43.890126
# 6/6 [==============================] - 9s 699ms/step - loss: 2.7682 - accuracy: 0.3328 - val_loss: 2.8871 - val_accuracy: 0.2894
# Epoch 3/25
#
# Training: batch 0 begins at 11:11:44.045552
#
# Training: batch 0 ends at 11:11:50.378830
# 1/6 [====>.........................] - ETA: 31s - loss: 2.7833 - accuracy: 0.3147
# Training: batch 1 begins at 11:11:50.386635
#
# Training: batch 1 ends at 11:11:50.769800
# 2/6 [=========>....................] - ETA: 1s - loss: 2.5912 - accuracy: 0.3868
# Training: batch 2 begins at 11:11:50.774762
#
# Training: batch 2 ends at 11:11:51.332929
# 3/6 [==============>...............] - ETA: 1s - loss: 2.6505 - accuracy: 0.3348
# Training: batch 3 begins at 11:11:51.336176
#
# Training: batch 3 ends at 11:11:51.706270
# 4/6 [===================>..........] - ETA: 0s - loss: 2.6259 - accuracy: 0.3548
# Training: batch 4 begins at 11:11:51.709329
#
# Training: batch 4 ends at 11:11:52.078500
# 5/6 [========================>.....] - ETA: 0s - loss: 2.6129 - accuracy: 0.3554
# Training: batch 5 begins at 11:11:52.081593
#
# Training: batch 5 ends at 11:11:53.032569
# 6/6 [==============================] - ETA: 0s - loss: 2.5624 - accuracy: 0.3630
# Evaluating: batch 0 begins at 11:11:53.091440
#
# Evaluating: batch 0 ends at 11:11:53.494411
#
# Evaluating: batch 1 begins at 11:11:53.497936
#
# Evaluating: batch 1 ends at 11:11:53.654896
#
# Evaluating: batch 2 begins at 11:11:53.656480
#
# Evaluating: batch 2 ends at 11:11:53.747752
#
# Evaluating: batch 3 begins at 11:11:53.749617
#
# Evaluating: batch 3 ends at 11:11:53.840116
#
# Evaluating: batch 4 begins at 11:11:53.842365
#
# Evaluating: batch 4 ends at 11:11:53.932406
#
# Evaluating: batch 5 begins at 11:11:53.934401
#
# Evaluating: batch 5 ends at 11:11:53.971892
# 6/6 [==============================] - 10s 721ms/step - loss: 2.5624 - accuracy: 0.3630 - val_loss: 2.7264 - val_accuracy: 0.2913
# Epoch 4/25
#
# Training: batch 0 begins at 11:11:54.127957
#
# Training: batch 0 ends at 11:11:57.914467
# 1/6 [====>.........................] - ETA: 18s - loss: 2.3132 - accuracy: 0.4080
# Training: batch 1 begins at 11:11:57.923422
#
# Training: batch 1 ends at 11:11:58.459789
# 2/6 [=========>....................] - ETA: 2s - loss: 2.3672 - accuracy: 0.3695
# Training: batch 2 begins at 11:11:58.462495
#
# Training: batch 2 ends at 11:11:59.749315
# 3/6 [==============>...............] - ETA: 2s - loss: 2.3620 - accuracy: 0.3594
# Training: batch 3 begins at 11:11:59.754715
#
# Training: batch 3 ends at 11:12:00.114993
# 4/6 [===================>..........] - ETA: 1s - loss: 2.3601 - accuracy: 0.3674
# Training: batch 4 begins at 11:12:00.117960
#
# Training: batch 4 ends at 11:12:00.470904
# 5/6 [========================>.....] - ETA: 0s - loss: 2.3447 - accuracy: 0.3691
# Training: batch 5 begins at 11:12:00.473967
#
# Training: batch 5 ends at 11:12:01.434298
# 6/6 [==============================] - ETA: 0s - loss: 2.3582 - accuracy: 0.3585
# Evaluating: batch 0 begins at 11:12:01.495853
#
# Evaluating: batch 0 ends at 11:12:01.977912
#
# Evaluating: batch 1 begins at 11:12:01.981384
#
# Evaluating: batch 1 ends at 11:12:02.144091
#
# Evaluating: batch 2 begins at 11:12:02.146978
#
# Evaluating: batch 2 ends at 11:12:02.237608
#
# Evaluating: batch 3 begins at 11:12:02.239241
#
# Evaluating: batch 3 ends at 11:12:02.328563
#
# Evaluating: batch 4 begins at 11:12:02.330102
#
# Evaluating: batch 4 ends at 11:12:02.422210
#
# Evaluating: batch 5 begins at 11:12:02.423720
#
# Evaluating: batch 5 ends at 11:12:02.463207
# 6/6 [==============================] - 8s 912ms/step - loss: 2.3582 - accuracy: 0.3585 - val_loss: 2.5060 - val_accuracy: 0.3039
# Epoch 5/25
#
# Training: batch 0 begins at 11:12:02.525561
#
# Training: batch 0 ends at 11:12:08.382004
# 1/6 [====>.........................] - ETA: 29s - loss: 2.3706 - accuracy: 0.3662
# Training: batch 1 begins at 11:12:08.391015
#
# Training: batch 1 ends at 11:12:09.226045
# 2/6 [=========>....................] - ETA: 3s - loss: 2.3021 - accuracy: 0.3676
# Training: batch 2 begins at 11:12:09.229107
#
# Training: batch 2 ends at 11:12:09.603838
# 3/6 [==============>...............] - ETA: 1s - loss: 2.3405 - accuracy: 0.3273
# Training: batch 3 begins at 11:12:09.606976
#
# Training: batch 3 ends at 11:12:09.975682
# 4/6 [===================>..........] - ETA: 1s - loss: 2.3163 - accuracy: 0.3271
# Training: batch 4 begins at 11:12:09.978106
#
# Training: batch 4 ends at 11:12:10.344995
# 5/6 [========================>.....] - ETA: 0s - loss: 2.2495 - accuracy: 0.3503
# Training: batch 5 begins at 11:12:10.348050
#
# Training: batch 5 ends at 11:12:11.524648
# 6/6 [==============================] - ETA: 0s - loss: 2.2306 - accuracy: 0.3595
# Evaluating: batch 0 begins at 11:12:11.583724
#
# Evaluating: batch 0 ends at 11:12:11.982222
#
# Evaluating: batch 1 begins at 11:12:11.983929
#
# Evaluating: batch 1 ends at 11:12:12.066911
#
# Evaluating: batch 2 begins at 11:12:12.068794
#
# Evaluating: batch 2 ends at 11:12:12.163281
#
# Evaluating: batch 3 begins at 11:12:12.164830
#
# Evaluating: batch 3 ends at 11:12:12.267925
#
# Evaluating: batch 4 begins at 11:12:12.270365
#
# Evaluating: batch 4 ends at 11:12:12.361016
#
# Evaluating: batch 5 begins at 11:12:12.362570
#
# Evaluating: batch 5 ends at 11:12:12.401533
# 6/6 [==============================] - 10s 806ms/step - loss: 2.2306 - accuracy: 0.3595 - val_loss: 2.2765 - val_accuracy: 0.2894
# Epoch 6/25
#
# Training: batch 0 begins at 11:12:12.533331
#
# Training: batch 0 ends at 11:12:16.336207
# 1/6 [====>.........................] - ETA: 19s - loss: 2.1334 - accuracy: 0.3878
# Training: batch 1 begins at 11:12:16.346902
#
# Training: batch 1 ends at 11:12:17.351638
# 2/6 [=========>....................] - ETA: 4s - loss: 2.1201 - accuracy: 0.3815
# Training: batch 2 begins at 11:12:17.355295
#
# Training: batch 2 ends at 11:12:18.405268
# 3/6 [==============>...............] - ETA: 3s - loss: 2.2649 - accuracy: 0.3162
# Training: batch 3 begins at 11:12:18.420338
#
# Training: batch 3 ends at 11:12:18.802215
# 4/6 [===================>..........] - ETA: 1s - loss: 2.1866 - accuracy: 0.3200
# Training: batch 4 begins at 11:12:18.805793
#
# Training: batch 4 ends at 11:12:19.172193
# 5/6 [========================>.....] - ETA: 0s - loss: 2.1473 - accuracy: 0.3455
# Training: batch 5 begins at 11:12:19.175596
#
# Training: batch 5 ends at 11:12:20.186158
# 6/6 [==============================] - ETA: 0s - loss: 2.1276 - accuracy: 0.3581
# Evaluating: batch 0 begins at 11:12:20.243461
#
# Evaluating: batch 0 ends at 11:12:20.645964
#
# Evaluating: batch 1 begins at 11:12:20.649241
#
# Evaluating: batch 1 ends at 11:12:20.782351
#
# Evaluating: batch 2 begins at 11:12:20.783764
#
# Evaluating: batch 2 ends at 11:12:20.874341
#
# Evaluating: batch 3 begins at 11:12:20.876212
#
# Evaluating: batch 3 ends at 11:12:20.971754
#
# Evaluating: batch 4 begins at 11:12:20.973470
#
# Evaluating: batch 4 ends at 11:12:21.064511
#
# Evaluating: batch 5 begins at 11:12:21.066325
#
# Evaluating: batch 5 ends at 11:12:21.105479
# 6/6 [==============================] - 9s 957ms/step - loss: 2.1276 - accuracy: 0.3581 - val_loss: 2.2006 - val_accuracy: 0.2963
# Epoch 7/25
#
# Training: batch 0 begins at 11:12:21.208692
#
# Training: batch 0 ends at 11:12:25.791523
# 1/6 [====>.........................] - ETA: 22s - loss: 2.1590 - accuracy: 0.3793
# Training: batch 1 begins at 11:12:25.799940
#
# Training: batch 1 ends at 11:12:26.376589
# 2/6 [=========>....................] - ETA: 2s - loss: 2.1154 - accuracy: 0.3417
# Training: batch 2 begins at 11:12:26.379114
#
# Training: batch 2 ends at 11:12:27.001627
# 3/6 [==============>...............] - ETA: 1s - loss: 2.0136 - accuracy: 0.3761
# Training: batch 3 begins at 11:12:27.004577
#
# Training: batch 3 ends at 11:12:27.389725
# 4/6 [===================>..........] - ETA: 1s - loss: 2.0007 - accuracy: 0.3842
# Training: batch 4 begins at 11:12:27.393890
#
# Training: batch 4 ends at 11:12:27.772448
# 5/6 [========================>.....] - ETA: 0s - loss: 2.0647 - accuracy: 0.3637
# Training: batch 5 begins at 11:12:27.775618
#
# Training: batch 5 ends at 11:12:28.821670
# 6/6 [==============================] - ETA: 0s - loss: 2.0445 - accuracy: 0.3649
# Evaluating: batch 0 begins at 11:12:28.884841
#
# Evaluating: batch 0 ends at 11:12:29.293241
#
# Evaluating: batch 1 begins at 11:12:29.296592
#
# Evaluating: batch 1 ends at 11:12:29.462868
#
# Evaluating: batch 2 begins at 11:12:29.464299
#
# Evaluating: batch 2 ends at 11:12:29.542121
#
# Evaluating: batch 3 begins at 11:12:29.543979
#
# Evaluating: batch 3 ends at 11:12:29.630396
#
# Evaluating: batch 4 begins at 11:12:29.631993
#
# Evaluating: batch 4 ends at 11:12:29.722080
#
# Evaluating: batch 5 begins at 11:12:29.723870
#
# Evaluating: batch 5 ends at 11:12:29.763379
# 6/6 [==============================] - 9s 797ms/step - loss: 2.0445 - accuracy: 0.3649 - val_loss: 2.1336 - val_accuracy: 0.2990
# Epoch 8/25
#
# Training: batch 0 begins at 11:12:29.900385
#
# Training: batch 0 ends at 11:12:34.493024
# 1/6 [====>.........................] - ETA: 23s - loss: 2.0142 - accuracy: 0.3956
# Training: batch 1 begins at 11:12:34.509195
#
# Training: batch 1 ends at 11:12:35.669493
# 2/6 [=========>....................] - ETA: 4s - loss: 2.0406 - accuracy: 0.3856
# Training: batch 2 begins at 11:12:35.673458
#
# Training: batch 2 ends at 11:12:36.053238
# 3/6 [==============>...............] - ETA: 2s - loss: 2.0052 - accuracy: 0.3837
# Training: batch 3 begins at 11:12:36.056392
#
# Training: batch 3 ends at 11:12:36.428010
# 4/6 [===================>..........] - ETA: 1s - loss: 2.0055 - accuracy: 0.3726
# Training: batch 4 begins at 11:12:36.431223
#
# Training: batch 4 ends at 11:12:36.799954
# 5/6 [========================>.....] - ETA: 0s - loss: 2.0234 - accuracy: 0.3615
# Training: batch 5 begins at 11:12:36.802565
#
# Training: batch 5 ends at 11:12:37.763443
# 6/6 [==============================] - ETA: 0s - loss: 2.0141 - accuracy: 0.3644
# Evaluating: batch 0 begins at 11:12:37.821068
#
# Evaluating: batch 0 ends at 11:12:38.327891
#
# Evaluating: batch 1 begins at 11:12:38.330721
#
# Evaluating: batch 1 ends at 11:12:38.440812
#
# Evaluating: batch 2 begins at 11:12:38.443675
#
# Evaluating: batch 2 ends at 11:12:38.531807
#
# Evaluating: batch 3 begins at 11:12:38.536148
#
# Evaluating: batch 3 ends at 11:12:38.626204
#
# Evaluating: batch 4 begins at 11:12:38.627753
#
# Evaluating: batch 4 ends at 11:12:38.719657
#
# Evaluating: batch 5 begins at 11:12:38.721302
#
# Evaluating: batch 5 ends at 11:12:38.759135
# 6/6 [==============================] - 9s 854ms/step - loss: 2.0141 - accuracy: 0.3644 - val_loss: 2.0688 - val_accuracy: 0.2999
# Epoch 9/25
#
# Training: batch 0 begins at 11:12:38.914039
#
# Training: batch 0 ends at 11:12:43.793033
# 1/6 [====>.........................] - ETA: 24s - loss: 2.0474 - accuracy: 0.3342
# Training: batch 1 begins at 11:12:43.801921
#
# Training: batch 1 ends at 11:12:44.446606
# 2/6 [=========>....................] - ETA: 2s - loss: 1.9561 - accuracy: 0.3770
# Training: batch 2 begins at 11:12:44.451286
#
# Training: batch 2 ends at 11:12:44.852161
# 3/6 [==============>...............] - ETA: 1s - loss: 2.0081 - accuracy: 0.3258
# Training: batch 3 begins at 11:12:44.856948
#
# Training: batch 3 ends at 11:12:45.286690
# 4/6 [===================>..........] - ETA: 0s - loss: 2.0174 - accuracy: 0.3323
# Training: batch 4 begins at 11:12:45.289966
#
# Training: batch 4 ends at 11:12:45.664030
# 5/6 [========================>.....] - ETA: 0s - loss: 2.0126 - accuracy: 0.3567
# Training: batch 5 begins at 11:12:45.666385
#
# Training: batch 5 ends at 11:12:46.693351
# 6/6 [==============================] - ETA: 0s - loss: 1.9907 - accuracy: 0.3659
# Evaluating: batch 0 begins at 11:12:46.749945
#
# Evaluating: batch 0 ends at 11:12:47.153930
#
# Evaluating: batch 1 begins at 11:12:47.157340
#
# Evaluating: batch 1 ends at 11:12:47.259479
#
# Evaluating: batch 2 begins at 11:12:47.262569
#
# Evaluating: batch 2 ends at 11:12:47.389337
#
# Evaluating: batch 3 begins at 11:12:47.391316
#
# Evaluating: batch 3 ends at 11:12:47.493819
#
# Evaluating: batch 4 begins at 11:12:47.495766
#
# Evaluating: batch 4 ends at 11:12:47.597559
#
# Evaluating: batch 5 begins at 11:12:47.599447
#
# Evaluating: batch 5 ends at 11:12:47.641240
# 6/6 [==============================] - 9s 772ms/step - loss: 1.9907 - accuracy: 0.3659 - val_loss: 2.0468 - val_accuracy: 0.2931
# Epoch 10/25
#
# Training: batch 0 begins at 11:12:47.730827
#
# Training: batch 0 ends at 11:12:51.467832
# 1/6 [====>.........................] - ETA: 18s - loss: 2.1182 - accuracy: 0.3387
# Training: batch 1 begins at 11:12:51.477609
#
# Training: batch 1 ends at 11:12:52.580448
# 2/6 [=========>....................] - ETA: 4s - loss: 1.9726 - accuracy: 0.3629
# Training: batch 2 begins at 11:12:52.585312
#
# Training: batch 2 ends at 11:12:53.209490
# 3/6 [==============>...............] - ETA: 2s - loss: 1.9821 - accuracy: 0.3576
# Training: batch 3 begins at 11:12:53.214285
#
# Training: batch 3 ends at 11:12:53.905552
# 4/6 [===================>..........] - ETA: 1s - loss: 1.9357 - accuracy: 0.3874
# Training: batch 4 begins at 11:12:53.909140
#
# Training: batch 4 ends at 11:12:54.275241
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9469 - accuracy: 0.3834
# Training: batch 5 begins at 11:12:54.278741
#
# Training: batch 5 ends at 11:12:55.220196
# 6/6 [==============================] - ETA: 0s - loss: 1.9408 - accuracy: 0.3657
# Evaluating: batch 0 begins at 11:12:55.280244
#
# Evaluating: batch 0 ends at 11:12:55.691125
#
# Evaluating: batch 1 begins at 11:12:55.694280
#
# Evaluating: batch 1 ends at 11:12:55.789487
#
# Evaluating: batch 2 begins at 11:12:55.791780
#
# Evaluating: batch 2 ends at 11:12:55.906960
#
# Evaluating: batch 3 begins at 11:12:55.908545
#
# Evaluating: batch 3 ends at 11:12:55.995680
#
# Evaluating: batch 4 begins at 11:12:55.997271
#
# Evaluating: batch 4 ends at 11:12:56.097867
#
# Evaluating: batch 5 begins at 11:12:56.099442
#
# Evaluating: batch 5 ends at 11:12:56.142561
# 6/6 [==============================] - 9s 1s/step - loss: 1.9408 - accuracy: 0.3657 - val_loss: 1.9892 - val_accuracy: 0.3045
# Epoch 11/25
#
# Training: batch 0 begins at 11:12:56.626128
#
# Training: batch 0 ends at 11:13:01.349837
# 1/6 [====>.........................] - ETA: 23s - loss: 2.0761 - accuracy: 0.2914
# Training: batch 1 begins at 11:13:01.364761
#
# Training: batch 1 ends at 11:13:01.917211
# 2/6 [=========>....................] - ETA: 2s - loss: 2.0511 - accuracy: 0.3322
# Training: batch 2 begins at 11:13:01.926416
#
# Training: batch 2 ends at 11:13:02.321942
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9898 - accuracy: 0.3535
# Training: batch 3 begins at 11:13:02.325241
#
# Training: batch 3 ends at 11:13:02.705125
# 4/6 [===================>..........] - ETA: 0s - loss: 1.9846 - accuracy: 0.3420
# Training: batch 4 begins at 11:13:02.708357
#
# Training: batch 4 ends at 11:13:03.129366
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9789 - accuracy: 0.3527
# Training: batch 5 begins at 11:13:03.133026
#
# Training: batch 5 ends at 11:13:04.313370
# 6/6 [==============================] - ETA: 0s - loss: 1.9433 - accuracy: 0.3690
# Evaluating: batch 0 begins at 11:13:04.373750
#
# Evaluating: batch 0 ends at 11:13:04.835954
#
# Evaluating: batch 1 begins at 11:13:04.839820
#
# Evaluating: batch 1 ends at 11:13:04.930540
#
# Evaluating: batch 2 begins at 11:13:04.932209
#
# Evaluating: batch 2 ends at 11:13:05.015743
#
# Evaluating: batch 3 begins at 11:13:05.017355
#
# Evaluating: batch 3 ends at 11:13:05.104764
#
# Evaluating: batch 4 begins at 11:13:05.106755
#
# Evaluating: batch 4 ends at 11:13:05.189488
#
# Evaluating: batch 5 begins at 11:13:05.190576
#
# Evaluating: batch 5 ends at 11:13:05.231259
# 6/6 [==============================] - 9s 777ms/step - loss: 1.9433 - accuracy: 0.3690 - val_loss: 1.9402 - val_accuracy: 0.3119
# Epoch 12/25
#
# Training: batch 0 begins at 11:13:05.369064
#
# Training: batch 0 ends at 11:13:09.899932
# 1/6 [====>.........................] - ETA: 22s - loss: 1.9551 - accuracy: 0.3679
# Training: batch 1 begins at 11:13:09.911837
#
# Training: batch 1 ends at 11:13:10.397140
# 2/6 [=========>....................] - ETA: 1s - loss: 1.9944 - accuracy: 0.3537
# Training: batch 2 begins at 11:13:10.400873
#
# Training: batch 2 ends at 11:13:11.020513
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9784 - accuracy: 0.3676
# Training: batch 3 begins at 11:13:11.025986
#
# Training: batch 3 ends at 11:13:11.581364
# 4/6 [===================>..........] - ETA: 1s - loss: 2.0223 - accuracy: 0.3491
# Training: batch 4 begins at 11:13:11.584578
#
# Training: batch 4 ends at 11:13:11.945419
# 5/6 [========================>.....] - ETA: 0s - loss: 2.0028 - accuracy: 0.3451
# Training: batch 5 begins at 11:13:11.948568
#
# Training: batch 5 ends at 11:13:12.897890
# 6/6 [==============================] - ETA: 0s - loss: 1.9715 - accuracy: 0.3646
# Evaluating: batch 0 begins at 11:13:12.959530
#
# Evaluating: batch 0 ends at 11:13:13.465113
#
# Evaluating: batch 1 begins at 11:13:13.468247
#
# Evaluating: batch 1 ends at 11:13:13.662608
#
# Evaluating: batch 2 begins at 11:13:13.664247
#
# Evaluating: batch 2 ends at 11:13:13.755457
#
# Evaluating: batch 3 begins at 11:13:13.757552
#
# Evaluating: batch 3 ends at 11:13:13.842610
#
# Evaluating: batch 4 begins at 11:13:13.844091
#
# Evaluating: batch 4 ends at 11:13:13.929076
#
# Evaluating: batch 5 begins at 11:13:13.930672
#
# Evaluating: batch 5 ends at 11:13:13.970426
# 6/6 [==============================] - 9s 817ms/step - loss: 1.9715 - accuracy: 0.3646 - val_loss: 1.9569 - val_accuracy: 0.3119
# Epoch 13/25
#
# Training: batch 0 begins at 11:13:14.118020
#
# Training: batch 0 ends at 11:13:17.455677
# 1/6 [====>.........................] - ETA: 17s - loss: 1.8386 - accuracy: 0.4654
# Training: batch 1 begins at 11:13:17.580393
#
# Training: batch 1 ends at 11:13:18.235353
# 2/6 [=========>....................] - ETA: 2s - loss: 1.8402 - accuracy: 0.4272
# Training: batch 2 begins at 11:13:18.240856
#
# Training: batch 2 ends at 11:13:19.772408
# 3/6 [==============>...............] - ETA: 3s - loss: 1.8623 - accuracy: 0.4245
# Training: batch 3 begins at 11:13:19.781859
#
# Training: batch 3 ends at 11:13:20.241841
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8669 - accuracy: 0.4044
# Training: batch 4 begins at 11:13:20.244948
#
# Training: batch 4 ends at 11:13:20.613446
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9168 - accuracy: 0.3804
# Training: batch 5 begins at 11:13:20.616918
#
# Training: batch 5 ends at 11:13:21.616058
# 6/6 [==============================] - ETA: 0s - loss: 1.9139 - accuracy: 0.3710
# Evaluating: batch 0 begins at 11:13:21.674309
#
# Evaluating: batch 0 ends at 11:13:22.273577
#
# Evaluating: batch 1 begins at 11:13:22.276088
#
# Evaluating: batch 1 ends at 11:13:22.371057
#
# Evaluating: batch 2 begins at 11:13:22.372639
#
# Evaluating: batch 2 ends at 11:13:22.467695
#
# Evaluating: batch 3 begins at 11:13:22.469592
#
# Evaluating: batch 3 ends at 11:13:22.569053
#
# Evaluating: batch 4 begins at 11:13:22.571189
#
# Evaluating: batch 4 ends at 11:13:22.657994
#
# Evaluating: batch 5 begins at 11:13:22.659385
#
# Evaluating: batch 5 ends at 11:13:22.691842
# 6/6 [==============================] - 9s 1s/step - loss: 1.9139 - accuracy: 0.3710 - val_loss: 1.9777 - val_accuracy: 0.3333
# Epoch 14/25
#
# Training: batch 0 begins at 11:13:22.800610
#
# Training: batch 0 ends at 11:13:27.846278
# 1/6 [====>.........................] - ETA: 25s - loss: 1.8268 - accuracy: 0.4017
# Training: batch 1 begins at 11:13:28.001159
#
# Training: batch 1 ends at 11:13:28.457753
# 2/6 [=========>....................] - ETA: 1s - loss: 1.9329 - accuracy: 0.3728
# Training: batch 2 begins at 11:13:28.461093
#
# Training: batch 2 ends at 11:13:28.862805
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9305 - accuracy: 0.3725
# Training: batch 3 begins at 11:13:28.865889
#
# Training: batch 3 ends at 11:13:29.245899
# 4/6 [===================>..........] - ETA: 0s - loss: 1.9216 - accuracy: 0.3683
# Training: batch 4 begins at 11:13:29.249035
#
# Training: batch 4 ends at 11:13:29.621530
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8977 - accuracy: 0.3850
# Training: batch 5 begins at 11:13:29.624549
#
# Training: batch 5 ends at 11:13:30.878341
# 6/6 [==============================] - ETA: 0s - loss: 1.9029 - accuracy: 0.3770
# Evaluating: batch 0 begins at 11:13:30.934348
#
# Evaluating: batch 0 ends at 11:13:31.310625
#
# Evaluating: batch 1 begins at 11:13:31.313015
#
# Evaluating: batch 1 ends at 11:13:31.399244
#
# Evaluating: batch 2 begins at 11:13:31.401106
#
# Evaluating: batch 2 ends at 11:13:31.495543
#
# Evaluating: batch 3 begins at 11:13:31.497206
#
# Evaluating: batch 3 ends at 11:13:31.579909
#
# Evaluating: batch 4 begins at 11:13:31.581923
#
# Evaluating: batch 4 ends at 11:13:31.666729
#
# Evaluating: batch 5 begins at 11:13:31.668401
#
# Evaluating: batch 5 ends at 11:13:31.706019
# 6/6 [==============================] - 9s 745ms/step - loss: 1.9029 - accuracy: 0.3770 - val_loss: 1.9113 - val_accuracy: 0.3211
# Epoch 15/25
#
# Training: batch 0 begins at 11:13:31.809631
#
# Training: batch 0 ends at 11:13:37.444582
# 1/6 [====>.........................] - ETA: 28s - loss: 1.8153 - accuracy: 0.3804
# Training: batch 1 begins at 11:13:37.452184
#
# Training: batch 1 ends at 11:13:37.882100
# 2/6 [=========>....................] - ETA: 1s - loss: 1.8083 - accuracy: 0.4236
# Training: batch 2 begins at 11:13:37.886484
#
# Training: batch 2 ends at 11:13:38.244304
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8688 - accuracy: 0.3827
# Training: batch 3 begins at 11:13:38.247395
#
# Training: batch 3 ends at 11:13:38.625227
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8623 - accuracy: 0.3869
# Training: batch 4 begins at 11:13:38.627499
#
# Training: batch 4 ends at 11:13:38.987878
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9022 - accuracy: 0.3700
# Training: batch 5 begins at 11:13:38.991279
#
# Training: batch 5 ends at 11:13:39.982362
# 6/6 [==============================] - ETA: 0s - loss: 1.9091 - accuracy: 0.3736
# Evaluating: batch 0 begins at 11:13:40.045438
#
# Evaluating: batch 0 ends at 11:13:40.514223
#
# Evaluating: batch 1 begins at 11:13:40.516777
#
# Evaluating: batch 1 ends at 11:13:40.681760
#
# Evaluating: batch 2 begins at 11:13:40.683322
#
# Evaluating: batch 2 ends at 11:13:40.769884
#
# Evaluating: batch 3 begins at 11:13:40.771740
#
# Evaluating: batch 3 ends at 11:13:40.861336
#
# Evaluating: batch 4 begins at 11:13:40.862893
#
# Evaluating: batch 4 ends at 11:13:40.956043
#
# Evaluating: batch 5 begins at 11:13:40.957639
#
# Evaluating: batch 5 ends at 11:13:40.994481
# 6/6 [==============================] - 9s 713ms/step - loss: 1.9091 - accuracy: 0.3736 - val_loss: 1.9207 - val_accuracy: 0.3280
# Epoch 16/25
#
# Training: batch 0 begins at 11:13:41.091451
#
# Training: batch 0 ends at 11:13:46.028332
# 1/6 [====>.........................] - ETA: 24s - loss: 1.9589 - accuracy: 0.3590
# Training: batch 1 begins at 11:13:46.036396
#
# Training: batch 1 ends at 11:13:47.054139
# 2/6 [=========>....................] - ETA: 4s - loss: 1.8945 - accuracy: 0.3826
# Training: batch 2 begins at 11:13:47.057503
#
# Training: batch 2 ends at 11:13:47.826581
# 3/6 [==============>...............] - ETA: 2s - loss: 1.9286 - accuracy: 0.3510
# Training: batch 3 begins at 11:13:47.831503
#
# Training: batch 3 ends at 11:13:48.202853
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8565 - accuracy: 0.3774
# Training: batch 4 begins at 11:13:48.206011
#
# Training: batch 4 ends at 11:13:48.570757
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8594 - accuracy: 0.3680
# Training: batch 5 begins at 11:13:48.574000
#
# Training: batch 5 ends at 11:13:49.602477
# 6/6 [==============================] - ETA: 0s - loss: 1.8615 - accuracy: 0.3829
# Evaluating: batch 0 begins at 11:13:49.660324
#
# Evaluating: batch 0 ends at 11:13:50.042430
#
# Evaluating: batch 1 begins at 11:13:50.046217
#
# Evaluating: batch 1 ends at 11:13:50.159896
#
# Evaluating: batch 2 begins at 11:13:50.161506
#
# Evaluating: batch 2 ends at 11:13:50.249331
#
# Evaluating: batch 3 begins at 11:13:50.251493
#
# Evaluating: batch 3 ends at 11:13:50.343508
#
# Evaluating: batch 4 begins at 11:13:50.345251
#
# Evaluating: batch 4 ends at 11:13:50.440215
#
# Evaluating: batch 5 begins at 11:13:50.441911
#
# Evaluating: batch 5 ends at 11:13:50.481828
# 6/6 [==============================] - 9s 893ms/step - loss: 1.8615 - accuracy: 0.3829 - val_loss: 1.8721 - val_accuracy: 0.3322
# Epoch 17/25
#
# Training: batch 0 begins at 11:13:50.576739
#
# Training: batch 0 ends at 11:13:54.601112
# 1/6 [====>.........................] - ETA: 20s - loss: 1.9054 - accuracy: 0.3577
# Training: batch 1 begins at 11:13:54.611742
#
# Training: batch 1 ends at 11:13:55.518000
# 2/6 [=========>....................] - ETA: 3s - loss: 1.8226 - accuracy: 0.3892
# Training: batch 2 begins at 11:13:55.523077
#
# Training: batch 2 ends at 11:13:56.136079
# 3/6 [==============>...............] - ETA: 2s - loss: 1.8435 - accuracy: 0.3795
# Training: batch 3 begins at 11:13:56.143268
#
# Training: batch 3 ends at 11:13:56.628232
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8733 - accuracy: 0.3806
# Training: batch 4 begins at 11:13:56.631546
#
# Training: batch 4 ends at 11:13:57.005986
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8772 - accuracy: 0.3743
# Training: batch 5 begins at 11:13:57.009007
#
# Training: batch 5 ends at 11:13:57.909850
# 6/6 [==============================] - ETA: 0s - loss: 1.8755 - accuracy: 0.3735
# Evaluating: batch 0 begins at 11:13:57.976514
#
# Evaluating: batch 0 ends at 11:13:58.429990
#
# Evaluating: batch 1 begins at 11:13:58.432702
#
# Evaluating: batch 1 ends at 11:13:58.636757
#
# Evaluating: batch 2 begins at 11:13:58.638509
#
# Evaluating: batch 2 ends at 11:13:58.728328
#
# Evaluating: batch 3 begins at 11:13:58.729875
#
# Evaluating: batch 3 ends at 11:13:58.819687
#
# Evaluating: batch 4 begins at 11:13:58.821350
#
# Evaluating: batch 4 ends at 11:13:58.903920
#
# Evaluating: batch 5 begins at 11:13:58.905761
#
# Evaluating: batch 5 ends at 11:13:58.943669
# 6/6 [==============================] - 9s 929ms/step - loss: 1.8755 - accuracy: 0.3735 - val_loss: 1.9299 - val_accuracy: 0.3333
# Epoch 18/25
#
# Training: batch 0 begins at 11:13:59.308627
#
# Training: batch 0 ends at 11:14:04.577860
# 1/6 [====>.........................] - ETA: 26s - loss: 1.8443 - accuracy: 0.3488
# Training: batch 1 begins at 11:14:04.591817
#
# Training: batch 1 ends at 11:14:05.020087
# 2/6 [=========>....................] - ETA: 1s - loss: 1.9233 - accuracy: 0.3400
# Training: batch 2 begins at 11:14:05.024092
#
# Training: batch 2 ends at 11:14:05.471157
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8679 - accuracy: 0.3420
# Training: batch 3 begins at 11:14:05.474210
#
# Training: batch 3 ends at 11:14:05.843665
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8393 - accuracy: 0.3469
# Training: batch 4 begins at 11:14:05.846691
#
# Training: batch 4 ends at 11:14:06.221167
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8346 - accuracy: 0.3532
# Training: batch 5 begins at 11:14:06.224371
#
# Training: batch 5 ends at 11:14:07.168081
# 6/6 [==============================] - ETA: 0s - loss: 1.8352 - accuracy: 0.3669
# Evaluating: batch 0 begins at 11:14:07.227907
#
# Evaluating: batch 0 ends at 11:14:07.831006
#
# Evaluating: batch 1 begins at 11:14:07.832563
#
# Evaluating: batch 1 ends at 11:14:07.910979
#
# Evaluating: batch 2 begins at 11:14:07.912514
#
# Evaluating: batch 2 ends at 11:14:08.001205
#
# Evaluating: batch 3 begins at 11:14:08.002752
#
# Evaluating: batch 3 ends at 11:14:08.093175
#
# Evaluating: batch 4 begins at 11:14:08.095225
#
# Evaluating: batch 4 ends at 11:14:08.178216
#
# Evaluating: batch 5 begins at 11:14:08.179718
#
# Evaluating: batch 5 ends at 11:14:08.218239
# 6/6 [==============================] - 9s 731ms/step - loss: 1.8352 - accuracy: 0.3669 - val_loss: 1.8408 - val_accuracy: 0.3775
# Epoch 19/25
#
# Training: batch 0 begins at 11:14:08.363752
#
# Training: batch 0 ends at 11:14:13.537141
# 1/6 [====>.........................] - ETA: 28s - loss: 1.9214 - accuracy: 0.3309
# Training: batch 1 begins at 11:14:14.012703
#
# Training: batch 1 ends at 11:14:14.466920
# 2/6 [=========>....................] - ETA: 1s - loss: 1.8985 - accuracy: 0.3662
# Training: batch 2 begins at 11:14:14.469811
#
# Training: batch 2 ends at 11:14:14.842318
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9502 - accuracy: 0.3450
# Training: batch 3 begins at 11:14:14.845410
#
# Training: batch 3 ends at 11:14:15.218065
# 4/6 [===================>..........] - ETA: 0s - loss: 1.9226 - accuracy: 0.3582
# Training: batch 4 begins at 11:14:15.220343
#
# Training: batch 4 ends at 11:14:15.592377
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8683 - accuracy: 0.3727
# Training: batch 5 begins at 11:14:15.595736
#
# Training: batch 5 ends at 11:14:16.515436
# 6/6 [==============================] - ETA: 0s - loss: 1.8492 - accuracy: 0.3804
# Evaluating: batch 0 begins at 11:14:16.582534
#
# Evaluating: batch 0 ends at 11:14:17.035390
#
# Evaluating: batch 1 begins at 11:14:17.037429
#
# Evaluating: batch 1 ends at 11:14:17.259805
#
# Evaluating: batch 2 begins at 11:14:17.261571
#
# Evaluating: batch 2 ends at 11:14:17.349520
#
# Evaluating: batch 3 begins at 11:14:17.351069
#
# Evaluating: batch 3 ends at 11:14:17.441567
#
# Evaluating: batch 4 begins at 11:14:17.443213
#
# Evaluating: batch 4 ends at 11:14:17.525271
#
# Evaluating: batch 5 begins at 11:14:17.527552
#
# Evaluating: batch 5 ends at 11:14:17.571125
# 6/6 [==============================] - 9s 776ms/step - loss: 1.8492 - accuracy: 0.3804 - val_loss: 1.8479 - val_accuracy: 0.3390
# Epoch 20/25
#
# Training: batch 0 begins at 11:14:18.347914
#
# Training: batch 0 ends at 11:14:21.732007
# 1/6 [====>.........................] - ETA: 17s - loss: 1.9604 - accuracy: 0.3641
# Training: batch 1 begins at 11:14:21.848112
#
# Training: batch 1 ends at 11:14:23.213805
# 2/6 [=========>....................] - ETA: 5s - loss: 1.8997 - accuracy: 0.3669
# Training: batch 2 begins at 11:14:23.218712
#
# Training: batch 2 ends at 11:14:23.637790
# 3/6 [==============>...............] - ETA: 2s - loss: 1.9062 - accuracy: 0.3511
# Training: batch 3 begins at 11:14:23.640894
#
# Training: batch 3 ends at 11:14:24.016601
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8863 - accuracy: 0.3639
# Training: batch 4 begins at 11:14:24.019039
#
# Training: batch 4 ends at 11:14:24.392954
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8542 - accuracy: 0.3826
# Training: batch 5 begins at 11:14:24.395967
#
# Training: batch 5 ends at 11:14:25.268940
# 6/6 [==============================] - ETA: 0s - loss: 1.8264 - accuracy: 0.3855
# Evaluating: batch 0 begins at 11:14:25.332671
#
# Evaluating: batch 0 ends at 11:14:25.768692
#
# Evaluating: batch 1 begins at 11:14:25.771767
#
# Evaluating: batch 1 ends at 11:14:25.922735
#
# Evaluating: batch 2 begins at 11:14:25.924043
#
# Evaluating: batch 2 ends at 11:14:26.013495
#
# Evaluating: batch 3 begins at 11:14:26.015350
#
# Evaluating: batch 3 ends at 11:14:26.104687
#
# Evaluating: batch 4 begins at 11:14:26.106322
#
# Evaluating: batch 4 ends at 11:14:26.197669
#
# Evaluating: batch 5 begins at 11:14:26.199189
#
# Evaluating: batch 5 ends at 11:14:26.236082
# 6/6 [==============================] - 8s 882ms/step - loss: 1.8264 - accuracy: 0.3855 - val_loss: 1.9265 - val_accuracy: 0.3319
# Epoch 21/25
#
# Training: batch 0 begins at 11:14:26.373372
#
# Training: batch 0 ends at 11:14:31.458325
# 1/6 [====>.........................] - ETA: 25s - loss: 1.9984 - accuracy: 0.3489
# Training: batch 1 begins at 11:14:31.491685
#
# Training: batch 1 ends at 11:14:31.902197
# 2/6 [=========>....................] - ETA: 1s - loss: 1.9408 - accuracy: 0.3904
# Training: batch 2 begins at 11:14:32.090804
#
# Training: batch 2 ends at 11:14:32.477257
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9522 - accuracy: 0.3744
# Training: batch 3 begins at 11:14:32.480360
#
# Training: batch 3 ends at 11:14:33.032034
# 4/6 [===================>..........] - ETA: 1s - loss: 1.9504 - accuracy: 0.3791
# Training: batch 4 begins at 11:14:33.035369
#
# Training: batch 4 ends at 11:14:33.402796
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9219 - accuracy: 0.3864
# Training: batch 5 begins at 11:14:33.406319
#
# Training: batch 5 ends at 11:14:34.376210
# 6/6 [==============================] - ETA: 0s - loss: 1.9376 - accuracy: 0.3656
# Evaluating: batch 0 begins at 11:14:34.436246
#
# Evaluating: batch 0 ends at 11:14:34.900228
#
# Evaluating: batch 1 begins at 11:14:34.903219
#
# Evaluating: batch 1 ends at 11:14:34.994290
#
# Evaluating: batch 2 begins at 11:14:34.995766
#
# Evaluating: batch 2 ends at 11:14:35.087764
#
# Evaluating: batch 3 begins at 11:14:35.089480
#
# Evaluating: batch 3 ends at 11:14:35.181939
#
# Evaluating: batch 4 begins at 11:14:35.183950
#
# Evaluating: batch 4 ends at 11:14:35.274784
#
# Evaluating: batch 5 begins at 11:14:35.276336
#
# Evaluating: batch 5 ends at 11:14:35.314957
# 6/6 [==============================] - 9s 771ms/step - loss: 1.9376 - accuracy: 0.3656 - val_loss: 1.9040 - val_accuracy: 0.3985
# Epoch 22/25
#
# Training: batch 0 begins at 11:14:35.466380
#
# Training: batch 0 ends at 11:14:39.539805
# 1/6 [====>.........................] - ETA: 20s - loss: 1.8521 - accuracy: 0.3586
# Training: batch 1 begins at 11:14:39.548827
#
# Training: batch 1 ends at 11:14:40.815364
# 2/6 [=========>....................] - ETA: 5s - loss: 1.9087 - accuracy: 0.3658
# Training: batch 2 begins at 11:14:40.818812
#
# Training: batch 2 ends at 11:14:41.215063
# 3/6 [==============>...............] - ETA: 2s - loss: 1.8898 - accuracy: 0.3654
# Training: batch 3 begins at 11:14:41.218282
#
# Training: batch 3 ends at 11:14:41.656340
# 4/6 [===================>..........] - ETA: 1s - loss: 1.9071 - accuracy: 0.3671
# Training: batch 4 begins at 11:14:41.664467
#
# Training: batch 4 ends at 11:14:42.041954
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9077 - accuracy: 0.3660
# Training: batch 5 begins at 11:14:42.045475
#
# Training: batch 5 ends at 11:14:43.113905
# 6/6 [==============================] - ETA: 0s - loss: 1.8933 - accuracy: 0.3722
# Evaluating: batch 0 begins at 11:14:43.171674
#
# Evaluating: batch 0 ends at 11:14:43.590855
#
# Evaluating: batch 1 begins at 11:14:43.594603
#
# Evaluating: batch 1 ends at 11:14:43.688961
#
# Evaluating: batch 2 begins at 11:14:43.690534
#
# Evaluating: batch 2 ends at 11:14:43.774148
#
# Evaluating: batch 3 begins at 11:14:43.775546
#
# Evaluating: batch 3 ends at 11:14:43.867193
#
# Evaluating: batch 4 begins at 11:14:43.868976
#
# Evaluating: batch 4 ends at 11:14:43.951323
#
# Evaluating: batch 5 begins at 11:14:43.952646
#
# Evaluating: batch 5 ends at 11:14:43.989805
# 6/6 [==============================] - 9s 892ms/step - loss: 1.8933 - accuracy: 0.3722 - val_loss: 1.8826 - val_accuracy: 0.3160
# Epoch 23/25
#
# Training: batch 0 begins at 11:14:44.065500
#
# Training: batch 0 ends at 11:14:48.936092
# 1/6 [====>.........................] - ETA: 24s - loss: 1.6710 - accuracy: 0.4281
# Training: batch 1 begins at 11:14:48.945953
#
# Training: batch 1 ends at 11:14:49.451490
# 2/6 [=========>....................] - ETA: 2s - loss: 1.8752 - accuracy: 0.3747
# Training: batch 2 begins at 11:14:49.455915
#
# Training: batch 2 ends at 11:14:49.935142
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8529 - accuracy: 0.3747
# Training: batch 3 begins at 11:14:49.939785
#
# Training: batch 3 ends at 11:14:50.380291
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8705 - accuracy: 0.3809
# Training: batch 4 begins at 11:14:50.384450
#
# Training: batch 4 ends at 11:14:50.940315
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8864 - accuracy: 0.3644
# Training: batch 5 begins at 11:14:50.943458
#
# Training: batch 5 ends at 11:14:51.851658
# 6/6 [==============================] - ETA: 0s - loss: 1.8710 - accuracy: 0.3700
# Evaluating: batch 0 begins at 11:14:51.908454
#
# Evaluating: batch 0 ends at 11:14:52.396889
#
# Evaluating: batch 1 begins at 11:14:52.398720
#
# Evaluating: batch 1 ends at 11:14:52.482295
#
# Evaluating: batch 2 begins at 11:14:52.483784
#
# Evaluating: batch 2 ends at 11:14:52.571858
#
# Evaluating: batch 3 begins at 11:14:52.573429
#
# Evaluating: batch 3 ends at 11:14:52.668477
#
# Evaluating: batch 4 begins at 11:14:52.670173
#
# Evaluating: batch 4 ends at 11:14:52.759387
#
# Evaluating: batch 5 begins at 11:14:52.761116
#
# Evaluating: batch 5 ends at 11:14:52.802330
# 6/6 [==============================] - 9s 776ms/step - loss: 1.8710 - accuracy: 0.3700 - val_loss: 1.8995 - val_accuracy: 0.3584
# Epoch 24/25
#
# Training: batch 0 begins at 11:14:52.863262
#
# Training: batch 0 ends at 11:14:56.698246
# 1/6 [====>.........................] - ETA: 19s - loss: 2.0630 - accuracy: 0.3469
# Training: batch 1 begins at 11:14:56.708197
#
# Training: batch 1 ends at 11:14:58.036345
# 2/6 [=========>....................] - ETA: 5s - loss: 2.0034 - accuracy: 0.3482
# Training: batch 2 begins at 11:14:58.041275
#
# Training: batch 2 ends at 11:14:58.528877
# 3/6 [==============>...............] - ETA: 2s - loss: 1.9399 - accuracy: 0.3671
# Training: batch 3 begins at 11:14:58.533688
#
# Training: batch 3 ends at 11:14:58.912174
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8924 - accuracy: 0.3756
# Training: batch 4 begins at 11:14:58.916481
#
# Training: batch 4 ends at 11:14:59.285707
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8961 - accuracy: 0.3629
# Training: batch 5 begins at 11:14:59.290461
#
# Training: batch 5 ends at 11:15:00.190700
# 6/6 [==============================] - ETA: 0s - loss: 1.8812 - accuracy: 0.3675
# Evaluating: batch 0 begins at 11:15:00.247286
#
# Evaluating: batch 0 ends at 11:15:00.658304
#
# Evaluating: batch 1 begins at 11:15:00.661400
#
# Evaluating: batch 1 ends at 11:15:00.889128
#
# Evaluating: batch 2 begins at 11:15:00.891009
#
# Evaluating: batch 2 ends at 11:15:00.979325
#
# Evaluating: batch 3 begins at 11:15:00.980760
#
# Evaluating: batch 3 ends at 11:15:01.071870
#
# Evaluating: batch 4 begins at 11:15:01.073377
#
# Evaluating: batch 4 ends at 11:15:01.166134
#
# Evaluating: batch 5 begins at 11:15:01.167982
#
# Evaluating: batch 5 ends at 11:15:01.207351
# 6/6 [==============================] - 8s 904ms/step - loss: 1.8812 - accuracy: 0.3675 - val_loss: 1.9127 - val_accuracy: 0.3206
# Epoch 25/25
#
# Training: batch 0 begins at 11:15:01.301102
#
# Training: batch 0 ends at 11:15:05.513332
# 1/6 [====>.........................] - ETA: 21s - loss: 1.9351 - accuracy: 0.3457
# Training: batch 1 begins at 11:15:05.528775
#
# Training: batch 1 ends at 11:15:06.679480
# 2/6 [=========>....................] - ETA: 4s - loss: 1.8926 - accuracy: 0.4013
# Training: batch 2 begins at 11:15:06.682709
#
# Training: batch 2 ends at 11:15:07.134620
# 3/6 [==============>...............] - ETA: 2s - loss: 1.8937 - accuracy: 0.3904
# Training: batch 3 begins at 11:15:07.138795
#
# Training: batch 3 ends at 11:15:07.618279
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8842 - accuracy: 0.3836
# Training: batch 4 begins at 11:15:07.622933
#
# Training: batch 4 ends at 11:15:07.999327
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8783 - accuracy: 0.3879
# Training: batch 5 begins at 11:15:08.002407
#
# Training: batch 5 ends at 11:15:09.139764
# 6/6 [==============================] - ETA: 0s - loss: 1.9079 - accuracy: 0.3661
# Evaluating: batch 0 begins at 11:15:09.204992
#
# Evaluating: batch 0 ends at 11:15:09.605435
#
# Evaluating: batch 1 begins at 11:15:09.608712
#
# Evaluating: batch 1 ends at 11:15:09.718425
#
# Evaluating: batch 2 begins at 11:15:09.719966
#
# Evaluating: batch 2 ends at 11:15:09.807131
#
# Evaluating: batch 3 begins at 11:15:09.809554
#
# Evaluating: batch 3 ends at 11:15:09.896998
#
# Evaluating: batch 4 begins at 11:15:09.898798
#
# Evaluating: batch 4 ends at 11:15:10.002767
#
# Evaluating: batch 5 begins at 11:15:10.004352
#
# Evaluating: batch 5 ends at 11:15:10.040239
# 6/6 [==============================] - 9s 906ms/step - loss: 1.9079 - accuracy: 0.3661 - val_loss: 1.8967 - val_accuracy: 0.3330
# Train hist recorded for batch -  0
# Saving the model
# INFO:tensorflow:Assets written to: saved_models/training_20/batch_0/assets
# Saved the model at saved_models/training_20/batch_0/
# UNet model loaded from  saved_models/training_20/batch_0/
# Reading train data
# x train ----  60
# x val ----  27
# Train and Validation data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:70: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/25
#
# Training: batch 0 begins at 11:15:43.994221
#
# Training: batch 0 ends at 11:15:51.201535
# 1/6 [====>.........................] - ETA: 36s - loss: 2.4549 - accuracy: 0.2048
# Training: batch 1 begins at 11:15:51.335110
#
# Training: batch 1 ends at 11:15:51.708694
# 2/6 [=========>....................] - ETA: 1s - loss: 2.3457 - accuracy: 0.2240
# Training: batch 2 begins at 11:15:51.711981
#
# Training: batch 2 ends at 11:15:52.076713
# 3/6 [==============>...............] - ETA: 1s - loss: 2.2795 - accuracy: 0.2155
# Training: batch 3 begins at 11:15:52.080349
#
# Training: batch 3 ends at 11:15:52.439715
# 4/6 [===================>..........] - ETA: 0s - loss: 2.2574 - accuracy: 0.2034
# Training: batch 4 begins at 11:15:52.443101
#
# Training: batch 4 ends at 11:15:52.824396
# 5/6 [========================>.....] - ETA: 0s - loss: 2.2306 - accuracy: 0.2093
# Training: batch 5 begins at 11:15:52.827638
#
# Training: batch 5 ends at 11:15:53.817948
# 6/6 [==============================] - ETA: 0s - loss: 2.1809 - accuracy: 0.2141
# Evaluating: batch 0 begins at 11:15:54.983199
#
# Evaluating: batch 0 ends at 11:15:56.129492
#
# Evaluating: batch 1 begins at 11:15:56.130708
#
# Evaluating: batch 1 ends at 11:15:56.204666
#
# Evaluating: batch 2 begins at 11:15:56.205832
#
# Evaluating: batch 2 ends at 11:15:56.278256
#
# Evaluating: batch 3 begins at 11:15:56.279218
#
# Evaluating: batch 3 ends at 11:15:56.709169
#
# Evaluating: batch 4 begins at 11:15:56.711260
#
# Evaluating: batch 4 ends at 11:15:56.784833
#
# Evaluating: batch 5 begins at 11:15:56.785751
#
# Evaluating: batch 5 ends at 11:15:56.817720
# 6/6 [==============================] - 13s 1s/step - loss: 2.1809 - accuracy: 0.2141 - val_loss: 1.9062 - val_accuracy: 0.2614
# Epoch 2/25
#
# Training: batch 0 begins at 11:15:56.929189
#
# Training: batch 0 ends at 11:16:01.870607
# 1/6 [====>.........................] - ETA: 24s - loss: 1.8845 - accuracy: 0.2305
# Training: batch 1 begins at 11:16:01.882589
#
# Training: batch 1 ends at 11:16:02.740954
# 2/6 [=========>....................] - ETA: 3s - loss: 1.9598 - accuracy: 0.2445
# Training: batch 2 begins at 11:16:02.744762
#
# Training: batch 2 ends at 11:16:03.179319
# 3/6 [==============>...............] - ETA: 1s - loss: 1.9229 - accuracy: 0.2508
# Training: batch 3 begins at 11:16:03.183530
#
# Training: batch 3 ends at 11:16:03.622060
# 4/6 [===================>..........] - ETA: 1s - loss: 1.9397 - accuracy: 0.2644
# Training: batch 4 begins at 11:16:03.625276
#
# Training: batch 4 ends at 11:16:03.997276
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9731 - accuracy: 0.2665
# Training: batch 5 begins at 11:16:04.001296
#
# Training: batch 5 ends at 11:16:04.970360
# 6/6 [==============================] - ETA: 0s - loss: 1.9810 - accuracy: 0.2720
# Evaluating: batch 0 begins at 11:16:05.026905
#
# Evaluating: batch 0 ends at 11:16:05.768230
#
# Evaluating: batch 1 begins at 11:16:05.769822
#
# Evaluating: batch 1 ends at 11:16:05.862519
#
# Evaluating: batch 2 begins at 11:16:05.864007
#
# Evaluating: batch 2 ends at 11:16:05.948215
#
# Evaluating: batch 3 begins at 11:16:05.949699
#
# Evaluating: batch 3 ends at 11:16:06.032854
#
# Evaluating: batch 4 begins at 11:16:06.034719
#
# Evaluating: batch 4 ends at 11:16:06.116989
#
# Evaluating: batch 5 begins at 11:16:06.118322
#
# Evaluating: batch 5 ends at 11:16:06.150034
# 6/6 [==============================] - 9s 858ms/step - loss: 1.9810 - accuracy: 0.2720 - val_loss: 1.8422 - val_accuracy: 0.3195
# Epoch 3/25
#
# Training: batch 0 begins at 11:16:06.249079
#
# Training: batch 0 ends at 11:16:10.281822
# 1/6 [====>.........................] - ETA: 20s - loss: 1.9722 - accuracy: 0.1973
# Training: batch 1 begins at 11:16:10.395219
#
# Training: batch 1 ends at 11:16:11.932594
# 2/6 [=========>....................] - ETA: 6s - loss: 1.8890 - accuracy: 0.2757
# Training: batch 2 begins at 11:16:11.937634
#
# Training: batch 2 ends at 11:16:12.382385
# 3/6 [==============>...............] - ETA: 3s - loss: 1.9465 - accuracy: 0.2289
# Training: batch 3 begins at 11:16:12.386299
#
# Training: batch 3 ends at 11:16:12.810598
# 4/6 [===================>..........] - ETA: 1s - loss: 1.9362 - accuracy: 0.2322
# Training: batch 4 begins at 11:16:12.814197
#
# Training: batch 4 ends at 11:16:13.185321
# 5/6 [========================>.....] - ETA: 0s - loss: 1.9208 - accuracy: 0.2482
# Training: batch 5 begins at 11:16:13.189509
#
# Training: batch 5 ends at 11:16:14.201082
# 6/6 [==============================] - ETA: 0s - loss: 1.9275 - accuracy: 0.2605
# Evaluating: batch 0 begins at 11:16:14.260208
#
# Evaluating: batch 0 ends at 11:16:14.829927
#
# ...
#
# Evaluating: batch 2 begins at 11:22:51.802545
#
# Evaluating: batch 2 ends at 11:22:51.891246
#
# Evaluating: batch 3 begins at 11:22:51.892886
#
# Evaluating: batch 3 ends at 11:22:51.986420
#
# Evaluating: batch 4 begins at 11:22:51.988498
#
# Evaluating: batch 4 ends at 11:22:52.072182
#
# Evaluating: batch 5 begins at 11:22:52.073954
#
# Evaluating: batch 5 ends at 11:22:52.117240
# 6/6 [==============================] - 9s 923ms/step - loss: 1.7994 - accuracy: 0.3921 - val_loss: 1.7317 - val_accuracy: 0.3263
# Epoch 17/25
#
# Training: batch 0 begins at 11:22:52.252770
#
# Training: batch 0 ends at 11:22:58.834546
# 1/6 [====>.........................] - ETA: 32s - loss: 1.8223 - accuracy: 0.3677
# Training: batch 1 begins at 11:22:58.842421
#
# Training: batch 1 ends at 11:22:59.313871
# 2/6 [=========>....................] - ETA: 1s - loss: 1.8472 - accuracy: 0.3622
# Training: batch 2 begins at 11:22:59.316995
#
# Training: batch 2 ends at 11:22:59.690107
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8366 - accuracy: 0.3517
# Training: batch 3 begins at 11:22:59.693743
#
# Training: batch 3 ends at 11:23:00.070822
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8259 - accuracy: 0.3705
# Training: batch 4 begins at 11:23:00.074163
#
# Training: batch 4 ends at 11:23:00.458076
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8615 - accuracy: 0.3686
# Training: batch 5 begins at 11:23:00.462207
#
# Training: batch 5 ends at 11:23:01.473135
# 6/6 [==============================] - ETA: 0s - loss: 1.8691 - accuracy: 0.3639
# Evaluating: batch 0 begins at 11:23:01.534822
#
# Evaluating: batch 0 ends at 11:23:02.043729
#
# Evaluating: batch 1 begins at 11:23:02.048440
#
# Evaluating: batch 1 ends at 11:23:02.132518
#
# Evaluating: batch 2 begins at 11:23:02.134042
#
# Evaluating: batch 2 ends at 11:23:02.213545
#
# Evaluating: batch 3 begins at 11:23:02.215124
#
# Evaluating: batch 3 ends at 11:23:02.307534
#
# Evaluating: batch 4 begins at 11:23:02.309515
#
# Evaluating: batch 4 ends at 11:23:02.392987
#
# Evaluating: batch 5 begins at 11:23:02.394602
#
# Evaluating: batch 5 ends at 11:23:02.434579
# 6/6 [==============================] - 11s 794ms/step - loss: 1.8691 - accuracy: 0.3639 - val_loss: 1.6718 - val_accuracy: 0.4156
# Epoch 18/25
#
# Training: batch 0 begins at 11:23:02.879587
#
# Training: batch 0 ends at 11:23:08.230468
# 1/6 [====>.........................] - ETA: 26s - loss: 1.8804 - accuracy: 0.3271
# Training: batch 1 begins at 11:23:08.237801
#
# Training: batch 1 ends at 11:23:08.671546
# 2/6 [=========>....................] - ETA: 1s - loss: 1.7615 - accuracy: 0.4264
# Training: batch 2 begins at 11:23:08.675765
#
# Training: batch 2 ends at 11:23:09.126810
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8070 - accuracy: 0.4049
# Training: batch 3 begins at 11:23:09.138597
#
# Training: batch 3 ends at 11:23:09.510968
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8225 - accuracy: 0.3863
# Training: batch 4 begins at 11:23:09.513288
#
# Training: batch 4 ends at 11:23:09.883436
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8538 - accuracy: 0.3796
# Training: batch 5 begins at 11:23:09.886895
#
# Training: batch 5 ends at 11:23:10.890661
# 6/6 [==============================] - ETA: 0s - loss: 1.8486 - accuracy: 0.3748
# Evaluating: batch 0 begins at 11:23:10.952293
#
# Evaluating: batch 0 ends at 11:23:11.493395
#
# Evaluating: batch 1 begins at 11:23:11.495268
#
# Evaluating: batch 1 ends at 11:23:11.582962
#
# Evaluating: batch 2 begins at 11:23:11.584614
#
# Evaluating: batch 2 ends at 11:23:11.674983
#
# Evaluating: batch 3 begins at 11:23:11.676515
#
# Evaluating: batch 3 ends at 11:23:11.769174
#
# Evaluating: batch 4 begins at 11:23:11.770977
#
# Evaluating: batch 4 ends at 11:23:11.855400
#
# Evaluating: batch 5 begins at 11:23:11.856870
#
# Evaluating: batch 5 ends at 11:23:11.904704
# 6/6 [==============================] - 9s 737ms/step - loss: 1.8486 - accuracy: 0.3748 - val_loss: 1.7774 - val_accuracy: 0.3289
# Epoch 19/25
#
# Training: batch 0 begins at 11:23:12.005088
#
# Training: batch 0 ends at 11:23:15.837897
# 1/6 [====>.........................] - ETA: 19s - loss: 1.7200 - accuracy: 0.4181
# Training: batch 1 begins at 11:23:15.975961
#
# Training: batch 1 ends at 11:23:17.657608
# 2/6 [=========>....................] - ETA: 7s - loss: 1.7480 - accuracy: 0.4070
# Training: batch 2 begins at 11:23:17.660937
#
# Training: batch 2 ends at 11:23:18.120233
# 3/6 [==============>...............] - ETA: 3s - loss: 1.7390 - accuracy: 0.4070
# Training: batch 3 begins at 11:23:18.125001
#
# Training: batch 3 ends at 11:23:18.517316
# 4/6 [===================>..........] - ETA: 1s - loss: 1.6962 - accuracy: 0.4117
# Training: batch 4 begins at 11:23:18.519841
#
# Training: batch 4 ends at 11:23:18.894906
# 5/6 [========================>.....] - ETA: 0s - loss: 1.7891 - accuracy: 0.3831
# Training: batch 5 begins at 11:23:18.898892
#
# Training: batch 5 ends at 11:23:19.920535
# 6/6 [==============================] - ETA: 0s - loss: 1.8080 - accuracy: 0.3798
# Evaluating: batch 0 begins at 11:23:19.980643
#
# Evaluating: batch 0 ends at 11:23:20.404616
#
# Evaluating: batch 1 begins at 11:23:20.408009
#
# Evaluating: batch 1 ends at 11:23:20.601169
#
# Evaluating: batch 2 begins at 11:23:20.602733
#
# Evaluating: batch 2 ends at 11:23:20.690247
#
# Evaluating: batch 3 begins at 11:23:20.692180
#
# Evaluating: batch 3 ends at 11:23:20.784167
#
# Evaluating: batch 4 begins at 11:23:20.785717
#
# Evaluating: batch 4 ends at 11:23:20.869077
#
# Evaluating: batch 5 begins at 11:23:20.870587
#
# Evaluating: batch 5 ends at 11:23:20.906844
# 6/6 [==============================] - 9s 1s/step - loss: 1.8080 - accuracy: 0.3798 - val_loss: 1.7006 - val_accuracy: 0.4161
# Epoch 20/25
#
# Training: batch 0 begins at 11:23:21.042709
#
# Training: batch 0 ends at 11:23:24.937338
# 1/6 [====>.........................] - ETA: 19s - loss: 1.6404 - accuracy: 0.4480
# Training: batch 1 begins at 11:23:24.949502
#
# Training: batch 1 ends at 11:23:26.552394
# 2/6 [=========>....................] - ETA: 6s - loss: 1.7838 - accuracy: 0.4043
# Training: batch 2 begins at 11:23:26.556405
#
# Training: batch 2 ends at 11:23:26.985119
# 3/6 [==============>...............] - ETA: 3s - loss: 1.7938 - accuracy: 0.3909
# Training: batch 3 begins at 11:23:26.988404
#
# Training: batch 3 ends at 11:23:27.466681
# 4/6 [===================>..........] - ETA: 1s - loss: 1.7610 - accuracy: 0.4163
# Training: batch 4 begins at 11:23:27.469962
#
# Training: batch 4 ends at 11:23:27.843343
# 5/6 [========================>.....] - ETA: 0s - loss: 1.7810 - accuracy: 0.3974
# Training: batch 5 begins at 11:23:27.846199
#
# Training: batch 5 ends at 11:23:28.778258
# 6/6 [==============================] - ETA: 0s - loss: 1.7926 - accuracy: 0.3870
# Evaluating: batch 0 begins at 11:23:28.838276
#
# Evaluating: batch 0 ends at 11:23:29.304555
#
# Evaluating: batch 1 begins at 11:23:29.308203
#
# Evaluating: batch 1 ends at 11:23:29.409007
#
# Evaluating: batch 2 begins at 11:23:29.410326
#
# Evaluating: batch 2 ends at 11:23:29.489123
#
# Evaluating: batch 3 begins at 11:23:29.490401
#
# Evaluating: batch 3 ends at 11:23:29.576072
#
# Evaluating: batch 4 begins at 11:23:29.577808
#
# Evaluating: batch 4 ends at 11:23:29.668426
#
# Evaluating: batch 5 begins at 11:23:29.669948
#
# Evaluating: batch 5 ends at 11:23:29.708667
# 6/6 [==============================] - 9s 957ms/step - loss: 1.7926 - accuracy: 0.3870 - val_loss: 1.7258 - val_accuracy: 0.3669
# Epoch 21/25
#
# Training: batch 0 begins at 11:23:29.791389
#
# Training: batch 0 ends at 11:23:34.004942
# 1/6 [====>.........................] - ETA: 21s - loss: 1.7739 - accuracy: 0.4294
# Training: batch 1 begins at 11:23:34.016021
#
# Training: batch 1 ends at 11:23:34.704052
# 2/6 [=========>....................] - ETA: 2s - loss: 1.8073 - accuracy: 0.3951
# Training: batch 2 begins at 11:23:34.712103
#
# Training: batch 2 ends at 11:23:35.190309
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8652 - accuracy: 0.3575
# Training: batch 3 begins at 11:23:35.320692
#
# Training: batch 3 ends at 11:23:35.720073
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8584 - accuracy: 0.3596
# Training: batch 4 begins at 11:23:35.725266
#
# Training: batch 4 ends at 11:23:36.157223
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8459 - accuracy: 0.3622
# Training: batch 5 begins at 11:23:36.160382
#
# Training: batch 5 ends at 11:23:37.198452
# 6/6 [==============================] - ETA: 0s - loss: 1.8265 - accuracy: 0.3784
# Evaluating: batch 0 begins at 11:23:37.259880
#
# Evaluating: batch 0 ends at 11:23:37.779324
#
# Evaluating: batch 1 begins at 11:23:37.783992
#
# Evaluating: batch 1 ends at 11:23:37.875220
#
# Evaluating: batch 2 begins at 11:23:37.876678
#
# Evaluating: batch 2 ends at 11:23:37.963587
#
# Evaluating: batch 3 begins at 11:23:37.965214
#
# Evaluating: batch 3 ends at 11:23:38.056591
#
# Evaluating: batch 4 begins at 11:23:38.058562
#
# Evaluating: batch 4 ends at 11:23:38.143026
#
# Evaluating: batch 5 begins at 11:23:38.144512
#
# Evaluating: batch 5 ends at 11:23:38.187969
# 6/6 [==============================] - 8s 839ms/step - loss: 1.8265 - accuracy: 0.3784 - val_loss: 1.7528 - val_accuracy: 0.4253
# Epoch 22/25
#
# Training: batch 0 begins at 11:23:38.311443
#
# Training: batch 0 ends at 11:23:44.308826
# 1/6 [====>.........................] - ETA: 30s - loss: 1.8909 - accuracy: 0.3974
# Training: batch 1 begins at 11:23:44.318765
#
# Training: batch 1 ends at 11:23:44.877770
# 2/6 [=========>....................] - ETA: 2s - loss: 1.9024 - accuracy: 0.4040
# Training: batch 2 begins at 11:23:44.884221
#
# Training: batch 2 ends at 11:23:45.258557
# 3/6 [==============>...............] - ETA: 1s - loss: 1.8785 - accuracy: 0.3944
# Training: batch 3 begins at 11:23:45.261935
#
# Training: batch 3 ends at 11:23:45.666974
# 4/6 [===================>..........] - ETA: 0s - loss: 1.8729 - accuracy: 0.3892
# Training: batch 4 begins at 11:23:45.669256
#
# Training: batch 4 ends at 11:23:46.039176
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8805 - accuracy: 0.3690
# Training: batch 5 begins at 11:23:46.042371
#
# Training: batch 5 ends at 11:23:47.036698
# 6/6 [==============================] - ETA: 0s - loss: 1.8864 - accuracy: 0.3593
# Evaluating: batch 0 begins at 11:23:47.097117
#
# Evaluating: batch 0 ends at 11:23:47.564699
#
# Evaluating: batch 1 begins at 11:23:47.568138
#
# Evaluating: batch 1 ends at 11:23:47.655960
#
# Evaluating: batch 2 begins at 11:23:47.657480
#
# Evaluating: batch 2 ends at 11:23:47.742939
#
# Evaluating: batch 3 begins at 11:23:47.744469
#
# Evaluating: batch 3 ends at 11:23:47.835891
#
# Evaluating: batch 4 begins at 11:23:47.837813
#
# Evaluating: batch 4 ends at 11:23:47.920256
#
# Evaluating: batch 5 begins at 11:23:47.921745
#
# Evaluating: batch 5 ends at 11:23:47.965630
# 6/6 [==============================] - 10s 734ms/step - loss: 1.8864 - accuracy: 0.3593 - val_loss: 1.6757 - val_accuracy: 0.3577
# Epoch 23/25
#
# Training: batch 0 begins at 11:23:48.083283
#
# Training: batch 0 ends at 11:23:52.291802
# 1/6 [====>.........................] - ETA: 21s - loss: 1.8946 - accuracy: 0.3477
# Training: batch 1 begins at 11:23:52.307746
#
# Training: batch 1 ends at 11:23:52.957030
# 2/6 [=========>....................] - ETA: 2s - loss: 1.8479 - accuracy: 0.3895
# Training: batch 2 begins at 11:23:52.964296
#
# Training: batch 2 ends at 11:23:53.885780
# 3/6 [==============>...............] - ETA: 2s - loss: 1.8554 - accuracy: 0.3670
# Training: batch 3 begins at 11:23:53.891326
#
# Training: batch 3 ends at 11:23:54.304404
# 4/6 [===================>..........] - ETA: 1s - loss: 1.8549 - accuracy: 0.3753
# Training: batch 4 begins at 11:23:54.308020
#
# Training: batch 4 ends at 11:23:54.677008
# 5/6 [========================>.....] - ETA: 0s - loss: 1.8429 - accuracy: 0.3838
# Training: batch 5 begins at 11:23:54.680468
#
# Training: batch 5 ends at 11:23:55.694482
# 6/6 [==============================] - ETA: 0s - loss: 1.8381 - accuracy: 0.3776
# Evaluating: batch 0 begins at 11:23:55.755269
#
# Evaluating: batch 0 ends at 11:23:56.160862
#
# Evaluating: batch 1 begins at 11:23:56.164088
#
# Evaluating: batch 1 ends at 11:23:56.399939
#
# Evaluating: batch 2 begins at 11:23:56.401735
#
# Evaluating: batch 2 ends at 11:23:56.489226
#
# Evaluating: batch 3 begins at 11:23:56.490768
#
# Evaluating: batch 3 ends at 11:23:56.574965
#
# Evaluating: batch 4 begins at 11:23:56.576565
#
# Evaluating: batch 4 ends at 11:23:56.667664
#
# Evaluating: batch 5 begins at 11:23:56.669484
#
# Evaluating: batch 5 ends at 11:23:56.712364
# 6/6 [==============================] - 9s 945ms/step - loss: 1.8381 - accuracy: 0.3776 - val_loss: 1.7789 - val_accuracy: 0.3453
# Epoch 24/25
#
# Training: batch 0 begins at 11:23:57.082398
#
# Training: batch 0 ends at 11:24:02.628495
# 1/6 [====>.........................] - ETA: 28s - loss: 1.8947 - accuracy: 0.3213
# Training: batch 1 begins at 11:24:02.734828
#
# Training: batch 1 ends at 11:24:03.188330
# 2/6 [=========>....................] - ETA: 1s - loss: 1.8282 - accuracy: 0.3389
# Training: batch 2 begins at 11:24:03.191425
#
# Training: batch 2 ends at 11:24:03.651734
# 3/6 [==============>...............] - ETA: 1s - loss: 1.7575 - accuracy: 0.3769
# Training: batch 3 begins at 11:24:03.655120
#
# Training: batch 3 ends at 11:24:04.026992
# 4/6 [===================>..........] - ETA: 0s - loss: 1.7349 - accuracy: 0.3870
# Training: batch 4 begins at 11:24:04.030546
#
# Training: batch 4 ends at 11:24:04.404711
# 5/6 [========================>.....] - ETA: 0s - loss: 1.7646 - accuracy: 0.3702
# Training: batch 5 begins at 11:24:04.407194
#
# Training: batch 5 ends at 11:24:05.531874
# 6/6 [==============================] - ETA: 0s - loss: 1.7227 - accuracy: 0.4015
# Evaluating: batch 0 begins at 11:24:05.591266
#
# Evaluating: batch 0 ends at 11:24:06.056283
#
# Evaluating: batch 1 begins at 11:24:06.058854
#
# Evaluating: batch 1 ends at 11:24:06.146491
#
# Evaluating: batch 2 begins at 11:24:06.147966
#
# Evaluating: batch 2 ends at 11:24:06.230933
#
# Evaluating: batch 3 begins at 11:24:06.232403
#
# Evaluating: batch 3 ends at 11:24:06.324538
#
# Evaluating: batch 4 begins at 11:24:06.326619
#
# Evaluating: batch 4 ends at 11:24:06.410279
#
# Evaluating: batch 5 begins at 11:24:06.411734
#
# Evaluating: batch 5 ends at 11:24:06.450185
# 6/6 [==============================] - 9s 748ms/step - loss: 1.7227 - accuracy: 0.4015 - val_loss: 1.6953 - val_accuracy: 0.3656
# Epoch 25/25
#
# Training: batch 0 begins at 11:24:06.527897
#
# Training: batch 0 ends at 11:24:10.517998
# 1/6 [====>.........................] - ETA: 19s - loss: 1.6460 - accuracy: 0.4359
# Training: batch 1 begins at 11:24:10.532319
#
# Training: batch 1 ends at 11:24:11.416719
# 2/6 [=========>....................] - ETA: 3s - loss: 1.7110 - accuracy: 0.3786
# Training: batch 2 begins at 11:24:11.422225
#
# Training: batch 2 ends at 11:24:12.837730
# 3/6 [==============>...............] - ETA: 3s - loss: 1.6649 - accuracy: 0.3908
# Training: batch 3 begins at 11:24:12.845790
#
# Training: batch 3 ends at 11:24:13.214744
# 4/6 [===================>..........] - ETA: 1s - loss: 1.6855 - accuracy: 0.3955
# Training: batch 4 begins at 11:24:13.218379
#
# Training: batch 4 ends at 11:24:13.588325
# 5/6 [========================>.....] - ETA: 0s - loss: 1.7058 - accuracy: 0.3920
# Training: batch 5 begins at 11:24:13.591394
#
# Training: batch 5 ends at 11:24:14.590288
# 6/6 [==============================] - ETA: 0s - loss: 1.6989 - accuracy: 0.3919
# Evaluating: batch 0 begins at 11:24:14.652194
#
# Evaluating: batch 0 ends at 11:24:15.164326
#
# Evaluating: batch 1 begins at 11:24:15.168480
#
# Evaluating: batch 1 ends at 11:24:15.242543
#
# Evaluating: batch 2 begins at 11:24:15.244056
#
# Evaluating: batch 2 ends at 11:24:15.324936
#
# Evaluating: batch 3 begins at 11:24:15.326550
#
# Evaluating: batch 3 ends at 11:24:15.415313
#
# Evaluating: batch 4 begins at 11:24:15.417221
#
# Evaluating: batch 4 ends at 11:24:15.499186
#
# Evaluating: batch 5 begins at 11:24:15.500595
#
# Evaluating: batch 5 ends at 11:24:15.544204
# 6/6 [==============================] - 9s 1s/step - loss: 1.6989 - accuracy: 0.3919 - val_loss: 1.5898 - val_accuracy: 0.5157
# Train hist recorded for batch -  2
# Saving the model
# INFO:tensorflow:Assets written to: saved_models/training_20/batch_2/assets
# Saved the model at saved_models/training_20/batch_2/

# %% [markdown]
# training_11 is the best train acc as of now but kaggle acc - 0.60
# training_13 is the best kaggle acc with 0.62
# training_12 - 261 - sftm kaggle acc was still 0.60
# training_15 - reduced epoch - kaggle 0.64
# training_16 - reduced epoch still - BEST kaggle 0.67
# training_19 - diff approach - 3 batches of 87 each - kaggle 0.66
# t_20 - 87-batch - model on 2 batch seems to perform good - kaggle 0.65

# %% [markdown]
# setttings for training_15:
#     if len(img_names) > 90:
#         EPOCHS = 35
#         print(" EPOCHS set to ", EPOCHS)
#     elif len(img_names) < 70:
#         EPOCHS = 5
#         print(" EPOCHS set to ", EPOCHS)
#     else:
#         EPOCHS = 20
#         print(" EPOCHS set to ", EPOCHS)
#     >>>>>>> and <<<<<<<<
#     90 - train; 10 - val

# %% [markdown]
# settings for training_16:
#     if len(img_names) > 90:
#         EPOCHS = 25
#         print("EPOCHS set to ", EPOCHS)
#     elif len(img_names) < 70:
#         EPOCHS = 5
#         print("EPOCHS set to ", EPOCHS)
#     else:
#         EPOCHS = 20
#         print("EPOCHS set to ", EPOCHS)
#         >>>>>>> and <<<<<<<
#     80 - train; 20 - val

# %% [markdown]
# settings for training_19:
# epochs = 20 >>>>>> and <<<<<< 70 - train; 17 - val
#
# settings for t_20:
# epochs = 20 and t/v = 60/27

# %% [markdown]
# ## Visualize Training history

# %%
def visualise_train_hist(hist_dict, metric="acc"):
    if metric == "loss":
        y_lbl = "Loss"
        titl = "Loss"
        
        train_met = "loss"
        train_lbl = "Train Loss"
        
        val_met = "val_loss"
        val_lbl = "Val Loss"
    else:
        y_lbl = "Accuracy"
        titl = "Accuracy"
        
        train_met = "accuracy"
        train_lbl = "Train Acc"
        
        val_met = "val_accuracy"
        val_lbl = "Val Acc"
        
        
    batch_0_hist = hist_dict[0]
    batch_1_hist = hist_dict[1]
    batch_2_hist = hist_dict[2]
    
    fig, axs = plt.subplots(1, 3, figsize=(15,5))
    
    axs[0].plot(batch_0_hist.epoch,batch_0_hist.history[val_met], color="red", label = val_lbl)
    axs[0].plot(batch_0_hist.epoch,batch_0_hist.history[train_met], color="blue", label = train_lbl)
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel(y_lbl)
    axs[0].set_title(titl + ' for Batch 1')
    axs[0].legend(loc='upper left')
    
    axs[1].plot(batch_1_hist.epoch,batch_1_hist.history[val_met], color="red", label = val_lbl)
    axs[1].plot(batch_1_hist.epoch,batch_1_hist.history[train_met], color="blue", label = train_lbl)
    axs[1].set_xlabel('Epochs')
    axs[1].set_title(titl + ' for Batch 2')
    axs[1].legend(loc='upper left')
    
    axs[2].plot(batch_2_hist.epoch,batch_2_hist.history[val_met], color="red", label = "Val Acc")
    axs[2].plot(batch_2_hist.epoch,batch_2_hist.history[train_met], color="blue", label = train_lbl)
    axs[2].set_xlabel('Epochs')
    axs[2].set_title(titl + ' for Batch 3')
    axs[2].legend(loc='upper left')

visualise_train_hist(train_hist) # , metric="loss"

# %%
def visualise_train_hist(hist_dict, metric="acc"):
    if metric == "loss":
        y_lbl = "Loss"
        titl = "Loss"
        
        train_met = "loss"
        train_lbl = "Train Loss"
        
        val_met = "val_loss"
        val_lbl = "Val Loss"
    else:
        y_lbl = "Accuracy"
        titl = "Accuracy"
        
        train_met = "accuracy"
        train_lbl = "Train Acc"
        
        val_met = "val_accuracy"
        val_lbl = "Val Acc"
        
        
    batch_0_hist = hist_dict[0]
    batch_1_hist = hist_dict[1]
    batch_2_hist = hist_dict[2]
    
    fig, axs = plt.subplots(1, 3, figsize=(15,5))
    
    axs[0].plot(batch_0_hist.epoch,batch_0_hist.history[val_met], color="red", label = val_lbl)
    axs[0].plot(batch_0_hist.epoch,batch_0_hist.history[train_met], color="blue", label = train_lbl)
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel(y_lbl)
    axs[0].set_title(titl + ' for Batch 1')
    axs[0].legend(loc='upper left')
    
    axs[1].plot(batch_1_hist.epoch,batch_1_hist.history[val_met], color="red", label = val_lbl)
    axs[1].plot(batch_1_hist.epoch,batch_1_hist.history[train_met], color="blue", label = train_lbl)
    axs[1].set_xlabel('Epochs')
    axs[1].set_title(titl + ' for Batch 2')
    axs[1].legend(loc='upper left')
    
    axs[2].plot(batch_2_hist.epoch,batch_2_hist.history[val_met], color="red", label = "Val Acc")
    axs[2].plot(batch_2_hist.epoch,batch_2_hist.history[train_met], color="blue", label = train_lbl)
    axs[2].set_xlabel('Epochs')
    axs[2].set_title(titl + ' for Batch 3')
    axs[2].legend(loc='upper left')

visualise_train_hist(train_hist) # , metric="loss"

# %% [markdown]
# ## Prediction

# %%
model

# %% [markdown]
# ### Test data
#
# Setting the path to test images. `test_y_loc` is the location where the predicted outputs should be saved.

# %%
test_x_loc = "/content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_images/"
test_y_loc = "/content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/"

# %% [markdown]
# Extract the names of the test images and sort them and store them in a list.

# %%
test_img_names = sorted([s[:-4] for s in os.listdir(test_x_loc)])

# %%
print("Number of test images = ", len(test_img_names))
# Out:
# Number of test images =  112

# %% [markdown]
# ### Ready the model

# %% [markdown]
# If `USE_CURRENT_MODEL` is False, then provide the location of the saved model you want to use in `SAVED_MODEL_LOC`.

# %%
USE_CURRENT_MODEL = True #False
SAVED_MODEL_LOC = TRAINING_SAVE_LOC + "batch_0/" # "saved_models/training_11/"

# %%
if not USE_CURRENT_MODEL:
    model = tf.keras.models.load_model(SAVED_MODEL_LOC)
    print("Model loaded from ", SAVED_MODEL_LOC)

# %% [markdown]
# ### Predict the output and save the mask as .png file

# %%
def get_predictions(image_loc, test_img_names):
    y_test = {}
    print("Predicting for {} images".format(len(test_img_names)))
    for i in test_img_names:
        print("Predicting for img",i)
        x_test = np.array(PIL.Image.open(image_loc + i + ".jpg").resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST))/255 #
        x_test = x_test.reshape((1,512,512,3))
        y_test[i] = model.predict(x_test, verbose=1)
        del x_test
    return y_test

def create_mask(image_dict):
    y_test_mask = {}
    print("Creating masks for {} predictions".format(len(image_dict)))
    for name, img in image_dict.items():
        pred_mask = tf.argmax(img, axis=3)
        pred_mask= np.uint8(pred_mask[0].numpy())
        y_test_mask[name] = pred_mask
    return y_test_mask
        
def save_mask(mask_dict):
    for name, mask in mask_dict.items():
        im = PIL.Image.fromarray(mask)
        im.save(test_y_loc + name + '.png')
        print("Image saved: ", test_y_loc + name + '.png')

preds = get_predictions(test_x_loc,test_img_names)
masks = create_mask(preds)
save_mask(masks)
# Out:
# Predicting for 112 images
# Predicting for img 10170
# 1/1 [==============================] - 1s 891ms/step
# Predicting for img 10171
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 10184
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 10566
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 10808
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 10812
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6413
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6424
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6427
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6450
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6455
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6457
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6459
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6462
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6463
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6465
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6466
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6476
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6481
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6492
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6499
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6504
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6546
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6550
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6560
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6569
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6574
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6608
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6644
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6648
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6654
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6656
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6657
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6662
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6677
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6701
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6710
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6717
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6795
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6804
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6854
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6856
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6901
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6908
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 6933
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6963
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6974
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 6982
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6994
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 6996
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7009
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7193
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7235
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7236
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7241
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7251
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7257
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7263
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7265
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7270
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7272
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7300
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7304
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7308
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7311
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7323
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7330
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7356
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7366
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7412
# 1/1 [==============================] - 0s 24ms/step
# Predicting for img 7415
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7422
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7427
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7429
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7438
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7457
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7466
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 7481
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7485
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7489
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7521
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7541
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7556
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7560
# 1/1 [==============================] - 0s 24ms/step
# Predicting for img 7580
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7582
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7586
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7593
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7597
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 7673
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7719
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7721
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 7829
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8361
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8516
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8526
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8774
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8786
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8833
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 8906
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 8947
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 8962
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 9006
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9070
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9079
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9084
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 9087
# 1/1 [==============================] - 0s 23ms/step
# Predicting for img 9101
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9106
# 1/1 [==============================] - 0s 21ms/step
# Predicting for img 9110
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9723
# 1/1 [==============================] - 0s 22ms/step
# Predicting for img 9795
# 1/1 [==============================] - 0s 23ms/step
# Creating masks for 112 predictions
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10170.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10171.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10184.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10566.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10808.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/10812.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6413.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6424.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6427.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6450.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6455.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6457.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6459.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6462.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6463.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6465.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6466.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6476.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6481.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6492.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6499.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6504.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6546.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6550.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6560.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6569.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6574.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6608.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6644.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6648.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6654.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6656.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6657.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6662.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6677.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6701.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6710.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6717.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6795.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6804.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6854.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6856.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6901.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6908.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6933.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6963.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6974.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6982.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6994.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/6996.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7009.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7193.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7235.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7236.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7241.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7251.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7257.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7263.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7265.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7270.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7272.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7300.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7304.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7308.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7311.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7323.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7330.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7356.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7366.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7412.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7415.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7422.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7427.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7429.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7438.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7457.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7466.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7481.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7485.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7489.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7521.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7541.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7556.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7560.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7580.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7582.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7586.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7593.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7597.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7673.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7719.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7721.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/7829.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8361.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8516.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8526.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8774.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8786.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8833.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8906.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8947.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/8962.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9006.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9070.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9079.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9084.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9087.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9101.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9106.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9110.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9723.png
# Image saved:  /content/drive/MyDrive/DL/test_images.zip (Unzipped Files)/test_preds/9795.png

# %% [markdown]
# ### Saving the output for kaggle submission

# %%
def rle_encode(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = img.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape)


def create_rles(test_pred_dir):
    """Used for Kaggle submission: predicts and encode all test images"""
    N = len([i for i in list(os.listdir(test_pred_dir)) if i[-3:] == "png"])
    with open('/content/drive/MyDrive/DL/submissions/submission_file6.csv', 'w') as f:
        f.write('ImageClassId,rle_mask\n')
        for index, i in enumerate(os.listdir(test_pred_dir)):
            if i[-3:] == "png":
                print('Saving {}/{}'.format(index, N))
                mask = PIL.Image.open(test_pred_dir + i)
                mask = mask.resize((1024, 1024), resample= PIL.Image.NEAREST)
                mask = np.array(mask)

                for x in range(1, 25):
                    enc = rle_encode(mask == x)
                    f.write(f"{i.split('_')[0]}_{x},{enc}\n")

create_rles(test_y_loc)
# Out:
# Saving 0/112
# Saving 1/112
# Saving 2/112
# Saving 3/112
# Saving 4/112
# Saving 5/112
# Saving 6/112
# Saving 7/112
# Saving 8/112
# Saving 9/112
# Saving 10/112
# Saving 11/112
# Saving 12/112
# Saving 13/112
# Saving 14/112
# Saving 15/112
# Saving 16/112
# Saving 17/112
# Saving 18/112
# Saving 19/112
# Saving 20/112
# Saving 21/112
# Saving 22/112
# Saving 23/112
# Saving 24/112
# Saving 25/112
# Saving 26/112
# Saving 27/112
# Saving 28/112
# Saving 29/112
# Saving 30/112
# Saving 31/112
# Saving 32/112
# Saving 33/112
# Saving 34/112
# Saving 35/112
# Saving 36/112
# Saving 37/112
# Saving 38/112
# Saving 39/112
# Saving 40/112
# Saving 41/112
# Saving 42/112
# Saving 43/112
# Saving 44/112
# Saving 45/112
# Saving 46/112
# Saving 47/112
# Saving 48/112
# Saving 49/112
# Saving 50/112
# Saving 51/112
# Saving 52/112
# Saving 53/112
# Saving 54/112
# Saving 55/112
# Saving 56/112
# Saving 57/112
# Saving 58/112
# Saving 59/112
# Saving 60/112
# Saving 61/112
# Saving 62/112
# Saving 63/112
# Saving 64/112
# Saving 65/112
# Saving 66/112
# Saving 67/112
# Saving 68/112
# Saving 69/112
# Saving 70/112
# Saving 71/112
# Saving 72/112
# Saving 73/112
# Saving 74/112
# Saving 75/112
# Saving 76/112
# Saving 77/112
# Saving 78/112
# Saving 79/112
# Saving 80/112
# Saving 81/112
# Saving 82/112
# Saving 83/112
# Saving 84/112
# Saving 85/112
# Saving 86/112
# Saving 87/112
# Saving 88/112
# Saving 89/112
# Saving 90/112
# Saving 91/112
# Saving 92/112
# Saving 93/112
# Saving 94/112
# Saving 95/112
# Saving 96/112
# Saving 97/112
# Saving 98/112
# Saving 99/112
# Saving 100/112
# Saving 101/112
# Saving 102/112
# Saving 103/112
# Saving 104/112
# Saving 105/112
# Saving 106/112
# Saving 107/112
# Saving 108/112
# Saving 109/112
# Saving 110/112
# Saving 111/112

# %% [markdown]
# ## Making a kaggle submission
#
# Make sure you have installed the kaggle package and completed all the steps listed here : https://medium.com/@jeff.daniel77/accessing-the-kaggle-com-api-with-jupyter-notebook-on-windows-d6f330bc6953

# %%
# !kaggle competitions submit -c fdl21-fdl-dsba -f submissions/submission_file.csv -m "batch 87 change t20 m0"
# Out:
# 100%|██████████████████████████████████████| 23.0M/23.0M [00:04<00:00, 5.80MB/s]
# Successfully submitted to FDL21: FDL-DSBA

# %% [markdown]
# ## Visualise the output of the model prediction

# %%
def visualise_test(image_name):

    img1 = np.array(PIL.Image.open(test_x_loc + image_name +'.jpg').resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST))/255
    img2 = mpimg.imread(test_y_loc + image_name +'.png')
    # mpimg.imread(test_x_loc + '6413.jpg')

    fig, axs = plt.subplots(1, 2, figsize=(15, 15))
    axs[0].imshow(img1)
    axs[0].set_title('Processed Img')
    axs[1].imshow(img2)
    axs[1].set_title('Predicted img')
    
def visualise_train(image_name):

    img1 = np.array(PIL.Image.open(train_x_loc + image_name +'.jpg').resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST))/255
    img2 = np.array(PIL.Image.open(train_y_loc + image_name + ".png").resize((INPUT_SIZE,INPUT_SIZE),resample=PIL.Image.NEAREST))
    # mpimg.imread(train_y_loc + image_name +'.png')
    # mpimg.imread(test_x_loc + '6413.jpg')

    img_name = [image_name]
    pred = get_predictions(train_x_loc,img_name)
    mask = create_mask(pred)
    print(mask.keys())
    img3 = mask[image_name]
    
    fig, axs = plt.subplots(1, 3, figsize=(15, 15))
    axs[0].imshow(img1)
    axs[0].set_title('Processed Img')
    axs[1].imshow(img2)
    axs[1].set_title('True Mask')
    axs[2].imshow(img3)
    axs[2].set_title('Predicted Mask')
    
assert(model is not None)
# visualise_test('') # provide only image names from 'train_images'
visualise_train('6456') # provide only image names from 'test_images'
# Out:
# Predicting for 1 images
# Predicting for img 6456
# 1/1 [==============================] - 0s 21ms/step
# Creating masks for 1 predictions
# dict_keys(['6456'])
